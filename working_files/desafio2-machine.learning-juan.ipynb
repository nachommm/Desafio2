# %% [markdown]
# <h2>Desafio 2 - Machine Learning

# %% [markdown]
# <h3>Grupo 7</h3>
# <ul>
#     <li>Ignacio Mendieta</li>
#     <li>Laura Jazmín Chao</li>
#     <li>Juan Nicolás Capistrano</li>
#     <li>Betiana Srur</li>
#     <li>Marecelo Carrizo</li>
#
# </ul>

# %% [markdown]
# **Desafio 2** : Aplicar las tecnicas de Machine Learning para calcular el precio por metro cuadrado de las propiedades.

# %%
import numpy as np
import pandas as pd
import re

# Libreria Grafica.
# %matplotlib inline
import seaborn as sns
from matplotlib import pyplot as plt

# Visualización
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import NumeralTickFormatter # Para imprimir los %
from bokeh.tile_providers import CARTODBPOSITRON, get_provider, Vendors 
from bokeh.resources import INLINE

# Libreria para analisis ML
from sklearn import datasets, linear_model

pd.set_option('display.max_columns', 100) # Para mostrar todas las columnas
pd.set_option('display.max_rows', 100) # Para mostrar todas las filas

# %%
# Definimos la ruta de la información.
data_propiedades = "Data/properati.csv"

# Leemos los datos del archivo
data = pd.read_csv(data_propiedades, sep=",", encoding="UTF-8")

# Chequeamos que los datos se hayan importado correctamente
data.sample(5)
# Out:
#         Unnamed: 0 operation property_type        place_name  \
# 117871      117871      sell         house           Córdoba
# 47524        47524      sell         house  Villa Pueyrredón
# 26872        26872      sell     apartment      Nueva Ciudad
# 76385        76385      sell     apartment   Lomas de Zamora
# 16357        16357      sell     apartment           Rosario
#
#                                   place_with_parent_names country_name  \
# 117871                        |Argentina|Córdoba|Córdoba|    Argentina
# 47524        |Argentina|Capital Federal|Villa Pueyrredón|    Argentina
# 26872                    |Argentina|Mendoza|Nueva Ciudad|    Argentina
# 76385   |Argentina|Bs.As. G.B.A. Zona Sur|Lomas de Zam...    Argentina
# 16357                        |Argentina|Santa Fe|Rosario|    Argentina
#
#                     state_name  geonames_id                  lat-lon  \
# 117871                 Córdoba    3860259.0                      NaN
# 47524          Capital Federal    3429703.0   -34.5866935,-58.506856
# 26872                  Mendoza          NaN  -32.8939961,-68.8047456
# 76385   Bs.As. G.B.A. Zona Sur          NaN    -34.75951,-58.3994779
# 16357                 Santa Fe    3838574.0  -32.9549993,-60.6337851
#
#               lat        lon      price currency  price_aprox_local_currency  \
# 117871        NaN        NaN  1950000.0      ARS                  1929658.27
# 47524  -34.586694 -58.506856   250000.0      USD                  4411125.00
# 26872  -32.893996 -68.804746        NaN      NaN                         NaN
# 76385  -34.759510 -58.399478   125000.0      USD                  2205562.50
# 16357  -32.954999 -60.633785  1110000.0      ARS                  1098420.94
#
#         price_aprox_usd  surface_total_in_m2  surface_covered_in_m2  \
# 117871        109363.16                  NaN                  110.0
# 47524         250000.00                250.0                  122.0
# 26872               NaN                100.0                  200.0
# 76385         125000.00                 64.0                   64.0
# 16357          62252.88                 35.0                   31.0
#
#         price_usd_per_m2  price_per_m2  floor  rooms  expenses  \
# 117871               NaN  17727.272727    NaN    NaN       NaN
# 47524        1000.000000   2049.180328    NaN    NaN       NaN
# 26872                NaN           NaN    NaN    5.0       NaN
# 76385        1953.125000   1953.125000    NaN    NaN       NaN
# 16357        1778.653714  35806.451613    NaN    NaN       NaN
#
#                                             properati_url  \
# 117871  http://www.properati.com.ar/1ce2f_venta_casa_c...
# 47524   http://www.properati.com.ar/198g8_venta_casa_v...
# 26872   http://www.properati.com.ar/17rmw_venta_depart...
# 76385   http://www.properati.com.ar/1arid_venta_depart...
# 16357   http://www.properati.com.ar/16yd3_venta_depart...
#
#                                               description  \
# 117871  “Nunca te dan un sueño sin concederte también ...
# 47524   CODIGO: 683-1292 ubicado en: Pje. Duarte N° 48...
# 26872   COMPLEJO DE DEPARTAMENTOS SOBRE CALLE PRINGLES...
# 76385   DEPARTAMENTO AL FRENTE consta de estar comedor...
# 16357   Edificio en construccion. Planta baja y 09 pis...
#
#                                                     title  \
# 117871                       Casa - Quebrada De Las Rosas
# 47524   CASA 3 AMB. CON GARAGE - PATIO - TERRAZA - A R...
# 26872           COMPLEJO DE DEPARTAMENTOS EN NUEVA CIUDAD
# 76385               Departamento en Lomas de Zamora Oeste
# 16357   Edificio en construccion. Amplios monoambiente...
#
#                                           image_thumbnail
# 117871  https://thumbs4.properati.com/7/-9r46jWa24fZag...
# 47524   https://thumbs4.properati.com/5/AyBC2qfqXS0jwr...
# 26872   https://thumbs4.properati.com/1/DII59KuGJ3GnFQ...
# 76385   https://thumbs4.properati.com/4/lCvLDiaydXzp4K...
# 16357   https://thumbs4.properati.com/7/XbfEEAj-il9CgD...

# %%
# Chequeamos cantidad de registros y cantidad de columnas
data.shape
# Out:
# (121220, 26)

# %% [markdown]
# <h2>Selección de los datos</h2>

# %% [markdown]
# En base a los análisis previos realizados sobre el Dataset, tomaremos los datos de CABA únicamente para realizar un modelo de machine learning.

# %%
# Creamos una máscara y la aplicamos al dataframe anterior para traer los registros que necesitamos
data_caba_mask = data.state_name == 'Capital Federal' 
data_caba = data.loc[data_caba_mask, :]

# Chequeamos cómo quedaron los datos
data_caba.head(3)
# Out:
#    Unnamed: 0 operation property_type place_name  \
# 0           0      sell            PH  Mataderos
# 2           2      sell     apartment  Mataderos
# 3           3      sell            PH    Liniers
#
#                  place_with_parent_names country_name       state_name  \
# 0  |Argentina|Capital Federal|Mataderos|    Argentina  Capital Federal
# 2  |Argentina|Capital Federal|Mataderos|    Argentina  Capital Federal
# 3    |Argentina|Capital Federal|Liniers|    Argentina  Capital Federal
#
#    geonames_id                  lat-lon        lat        lon    price  \
# 0    3430787.0  -34.6618237,-58.5088387 -34.661824 -58.508839  62000.0
# 2    3430787.0  -34.6522615,-58.5229825 -34.652262 -58.522982  72000.0
# 3    3431333.0  -34.6477969,-58.5164244 -34.647797 -58.516424  95000.0
#
#   currency  price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# 0      USD                   1093959.0          62000.0                 55.0
# 2      USD                   1270404.0          72000.0                 55.0
# 3      USD                   1676227.5          95000.0                  NaN
#
#    surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  rooms  \
# 0                   40.0       1127.272727   1550.000000    NaN    NaN
# 2                   55.0       1309.090909   1309.090909    NaN    NaN
# 3                    NaN               NaN           NaN    NaN    NaN
#
#    expenses                                      properati_url  \
# 0       NaN  http://www.properati.com.ar/15bo8_venta_ph_mat...
# 2       NaN  http://www.properati.com.ar/15bod_venta_depart...
# 3       NaN  http://www.properati.com.ar/15boh_venta_ph_lin...
#
#                                          description  \
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 ambientes con patio. Hay 3 deptos en lote...
#
#                                       title  \
# 0        2 AMB TIPO CASA SIN EXPENSAS EN PB
# 2  2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3              PH 3 amb. cfte. reciclado
#
#                                      image_thumbnail
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIK...
# 2  https://thumbs4.properati.com/5/SXKr34F_IwG3W_...
# 3  https://thumbs4.properati.com/3/DgIfX-85Mog5SP...

# %%
data_caba.shape
# Out:
# (32316, 26)

# %%
data_caba.dtypes
# Out:
# Unnamed: 0                      int64
# operation                      object
# property_type                  object
# place_name                     object
# place_with_parent_names        object
# country_name                   object
# state_name                     object
# geonames_id                   float64
# lat-lon                        object
# lat                           float64
# lon                           float64
# price                         float64
# currency                       object
# price_aprox_local_currency    float64
# price_aprox_usd               float64
# surface_total_in_m2           float64
# surface_covered_in_m2         float64
# price_usd_per_m2              float64
# price_per_m2                  float64
# floor                         float64
# rooms                         float64
# expenses                      float64
# properati_url                  object
# description                    object
# title                          object
# image_thumbnail                object
# dtype: object

# %% [markdown]
# <a id="section_dataset_nulos"></a>
# <h3>Cálculo de cantidad de nulos</h3>
#
# [volver a TOC](#section_toc)

# %%
# # Calculamos cantidad de nulos por campo
# cant_nulos_por_campo = data_caba.isnull().sum()
# cant_nulos_por_campo

# %%
# # Calculamos porcentaje de nulos por campo
# cant_registros = data_caba.shape[0]
# print(f'Cantidad Original de registros: {cant_registros}\n')
# #len(data.index) es lo mismo

# porc_nulos_por_campo = np.round((100 * cant_nulos_por_campo / cant_registros),2)
# print(porc_nulos_por_campo)

# %% [markdown]
# <h4> Distribución de <strong>property_type</strong>

# %%
# Contamos cantidad de valores de cada elemento en property_type y operation para ver distribución
property_type_count = data_caba.property_type.value_counts()
print(f'property_type: \n{property_type_count}')
# Out:
# property_type:
# apartment    27037
# house         2087
# PH            1828
# store         1364
# Name: property_type, dtype: int64

# %%
# # Convertimos el count anterior en las categorías del gráfico
# categories = np.array(property_type_count.index)

# cord_x = data_caba.property_type.value_counts() / data_caba.shape[0]
# palette = ['#440154', '#29788E', '#22A784', '#FDE724']

# p = figure(x_range=categories, plot_width=500, plot_height=200)
# p.vbar(x=categories, top=cord_x, width=0.6,
#        color=palette)

# p.yaxis.formatter = NumeralTickFormatter(format='0 %')
# output_notebook(resources=INLINE)
# show(p)

# %% [markdown]
# <h4>Distribución de <strong>currency</strong></h4>

# %%
data_caba.currency.value_counts()
# Out:
# USD    27826
# ARS     1190
# PEN        2
# Name: currency, dtype: int64

# %% [markdown]
# <h4>Distribución de <strong>barrio</strong></h4>

# %%
place_name_count = data_caba.place_name.value_counts()
# place_name_count.sort_index()
place_name_count
# Out:
# Belgrano                2992
# Palermo                 2885
# Caballito               2273
# Villa Urquiza           1629
# Recoleta                1547
# Flores                  1354
# Villa Crespo            1331
# Capital Federal         1297
# San Telmo               1216
# Almagro                 1165
# Barrio Norte            1140
# Boedo                    890
# Nuñez                    778
# Balvanera                667
# Puerto Madero            647
# San Cristobal            614
# Saavedra                 542
# Monserrat                538
# Palermo Hollywood        532
# Floresta                 516
# Villa del Parque         488
# Villa Luro               432
# Barracas                 425
# Villa Devoto             420
# Mataderos                418
# Liniers                  408
# Palermo Soho             394
# Colegiales               352
# Parque Patricios         322
# Congreso                 304
# Coghlan                  259
# Retiro                   248
# Palermo Chico            232
# Chacarita                227
# Boca                     223
# Centro / Microcentro     223
# Constitución             211
# Villa Lugano             205
# Once                     198
# San Nicolás              187
# Villa Pueyrredón         175
# Paternal                 173
# Parque Chacabuco         146
# Las Cañitas              143
# Abasto                   113
# Tribunales                98
# Villa Ortuzar             86
# Monte Castro              79
# Parque Centenario         68
# Pompeya                   64
# Villa Santa Rita          57
# Parque Avellaneda         56
# Versalles                 55
# Villa General Mitre       48
# Parque Chas               44
# Agronomía                 41
# Palermo Viejo             40
# Velez Sarsfield           39
# Villa Real                37
# Villa Soldati             15
# Villa Riachuelo            6
# Catalinas                  4
# Name: place_name, dtype: int64

# %% [markdown]
# <h2>Limpieza de Datos</h2>

# %% [markdown]
# <a id="section_dataset_drop"></a>
# <h3> Drop de columnas innecesarias </h3>
#
# [volver a TOC](#section_toc)

# %%
# Creamos la lista de columnas a filtrar
drop_columns = ['Unnamed: 0', 'operation', 'place_with_parent_names', 'country_name', 'state_name', 'geonames_id', 'lat-lon','lat', 'lon',
               'expenses','properati_url','title', 'image_thumbnail']

data_caba_clean = data_caba.drop(drop_columns, axis=1)
data_caba_clean.head(5)
# Out:
#   property_type place_name     price currency  price_aprox_local_currency  \
# 0            PH  Mataderos   62000.0      USD                   1093959.0
# 2     apartment  Mataderos   72000.0      USD                   1270404.0
# 3            PH    Liniers   95000.0      USD                   1676227.5
# 7     apartment   Belgrano  138000.0      USD                   2434941.0
# 8     apartment   Belgrano  195000.0      USD                   3440677.5
#
#    price_aprox_usd  surface_total_in_m2  surface_covered_in_m2  \
# 0          62000.0                 55.0                   40.0
# 2          72000.0                 55.0                   55.0
# 3          95000.0                  NaN                    NaN
# 7         138000.0                 45.0                   40.0
# 8         195000.0                 65.0                   60.0
#
#    price_usd_per_m2  price_per_m2  floor  rooms  \
# 0       1127.272727   1550.000000    NaN    NaN
# 2       1309.090909   1309.090909    NaN    NaN
# 3               NaN           NaN    NaN    NaN
# 7       3066.666667   3450.000000    NaN    NaN
# 8       3000.000000   3250.000000    NaN    NaN
#
#                                          description
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 ambientes con patio. Hay 3 deptos en lote...
# 7  EXCELENTE MONOAMBIENTE A ESTRENAR AMPLIO SUPER...
# 8  EXCELENTE DOS AMBIENTES  ESTRENAR AMPLIO SUPER...

# %% [markdown]
# <h3> Limpiamos <strong>currency</strong> </h3>
#
# [volver a TOC](#section_toc)

# %%
# Creamos una mask para traer los valores en monedas que no son USD ni ARS.
currency_OTHER_CURRENCY_mask = (data_caba_clean.currency == 'PEN') | (data_caba_clean.currency == 'UYU')
# Observamos esos registros
data_caba_clean.loc[currency_OTHER_CURRENCY_mask, :]
# Out:
#       property_type       place_name     price currency  \
# 50387     apartment  Capital Federal  380000.0      PEN
# 50388     apartment  Capital Federal  950000.0      PEN
#
#        price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# 50387                  2066864.90        117139.33                  NaN
# 50388                  5167162.35        292848.33                  NaN
#
#        surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  rooms  \
# 50387                    NaN               NaN           NaN    NaN    NaN
# 50388                    NaN               NaN           NaN    NaN    NaN
#
#                                              description
# 50387  Ref.: 55:PREVENTA ::: OPORTUNIDAD ::: Dúplex a...
# 50388  Ref.: 56Duplex en venta de 1 dormitorio con ap...

# %%
# Hacemos drop de esos registros y chequeamos la diferencia entre cantidad original y actual
cant_registros = data_caba_clean.shape[0]
# Dropeamos las moneda PEN y UYU ## OJO la moneda UYU era de una propiedad en Mendoza.
data_caba_clean.drop(data_caba_clean.loc[currency_OTHER_CURRENCY_mask, :].index, inplace = True) 
# Verificamos.
print(f'Cantidad de registros original - registro actuales: {cant_registros - data_caba_clean.shape[0]}')
# Out:
# Cantidad de registros original - registro actuales: 2

# %% [markdown]
# <h3> Limpiamos <strong>place_name</strong> </h3>
#
# [volver a TOC](#section_toc)

# %%
# Dropeamos los de Capital Federal
capi_mask = data_caba_clean.place_name == 'Capital Federal'
data_caba_clean.drop(data_caba_clean.loc[capi_mask, :].index, inplace=True)

# Chequeamos cómo quedaron los datos
data_caba_clean.shape
# Out:
# (31019, 13)

# %% [markdown]
# <h3> Volvemos a calcular cantidad de nulos luego de eliminar columnas y registros

# %%
# Calculamos cantidad de nulos por campo
cant_nulos_por_campo = data_caba_clean.isnull().sum()
cant_nulos_por_campo
# Out:
# property_type                     0
# place_name                        0
# price                          2959
# currency                       2959
# price_aprox_local_currency     2959
# price_aprox_usd                2959
# surface_total_in_m2            5707
# surface_covered_in_m2          1963
# price_usd_per_m2               8416
# price_per_m2                   4570
# floor                         28070
# rooms                         15748
# description                       0
# dtype: int64

# %%
# Calculamos porcentaje de nulos por campo
cant_registros = data_caba_clean.shape[0]
print(f'Cantidad Original de registros: {cant_registros}\n')
#len(data.index) es lo mismo

porc_nulos_por_campo = np.round((100 * cant_nulos_por_campo / cant_registros),2)
print(porc_nulos_por_campo)
# Out:
# Cantidad Original de registros: 31019
#
# property_type                  0.00
# place_name                     0.00
# price                          9.54
# currency                       9.54
# price_aprox_local_currency     9.54
# price_aprox_usd                9.54
# surface_total_in_m2           18.40
# surface_covered_in_m2          6.33
# price_usd_per_m2              27.13
# price_per_m2                  14.73
# floor                         90.49
# rooms                         50.77
# description                    0.00
# dtype: float64

# %%
data_caba_clean.shape
# Out:
# (31019, 13)

# %%
data_caba_clean.sample(5)
# Out:
#       property_type     place_name     price currency  \
# 78051     apartment  Villa Urquiza  240000.0      USD
# 1616      apartment       Recoleta  227000.0      USD
# 58942     apartment   Barrio Norte   53000.0      USD
# 48671         house        Coghlan  258000.0      USD
# 26807     apartment       Belgrano  185000.0      USD
#
#        price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# 78051                   4234680.0         240000.0                 80.0
# 1616                    4005301.5         227000.0                 66.0
# 58942                    935158.5          53000.0                 16.0
# 48671                   4552281.0         258000.0                  NaN
# 26807                   3264232.5         185000.0                 89.0
#
#        surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  rooms  \
# 78051                   72.0       3000.000000   3333.333333    NaN    NaN
# 1616                    32.0       3439.393939   7093.750000    NaN    1.0
# 58942                   16.0       3312.500000   3312.500000    NaN    NaN
# 48671                  245.0               NaN   1053.061224    NaN    4.0
# 26807                   89.0       2078.651685   2078.651685    NaN    4.0
#
#                                              description
# 78051  Cómodo y funcional departamento de 4 ambientes...
# 1616   R Peña 1700. Impecable monoambiente con balcón...
# 58942  CODIGO: 2905-SCH11 ubicado en: Uriburu 600  - ...
# 48671  Corredor Responsable: SABRINA COCCONI - CSI 62...
# 26807  Depto de 4 amb con dependencia al frente con b...

# %% [markdown]
# ## De los datos filtrados según Desafio 1 deberiamos:
#
# 1. Terminar de dropear variables incompletas que serian necesarias para poder entrenar un modelo. (ejemplo: si la propiedad no posee: price, price_aprox_local_currency,price_usd_per_m2, price_per_m2, etc...) la información de los barrios ya fue analizado y dropeado en el paso anterior.
# 2. Definir las variables CUANTITATIVAS, ejemplo precio, total de m2 de superficie.
# 3. Armar las variables CUALITATIVAS, Dummy (ejemplo: place_name, property_type, amenities, rooms).
# 4. Armar una nueva variable Dummy que contemple los precios de propiedad segun su distribución por metro cuadrado. Utilizando Panda CUT.
#
# ## Finalizado el analisis de datos, armamos diferentes modelos para predecir el precio de la propiedad.
#
# 1. Regresion Lineal Multiple
# 2. Entrenar los modelos con Lasso, RidgeCV y utilizando Cross Validation.

# %% [markdown]
# ### Primero damos homogenidad a los datos
#
# Vamos a realizar ciertas verificaciones de los datos.

# %%
# 1. Verificamos que el price y el price_aprox_usd sean los mismos, y luego si fuera así dropeamos el price_aprox_usd

mask_price_validation = data_caba_clean.price != data_caba_clean.price_aprox_usd

display(data_caba_clean.loc[mask_price_validation, :].shape)

# Detectamos que hay 4138 propiedades donde los valores son diferentes? pero estan en Pesos o son NaN?

display(data_caba_clean.loc[mask_price_validation, :].sample(10))

# Detectamos que tenemos los dos casos, donde los precios son NaN y donde la moneda está en ARS (lo cual no estaría mal)
# En el caso de ARS, vemos que el valor de price toma el de la moneda local ~ Por lo que podriamos llegar a eliminar price, currency y price_aprox_local_currency 

# Para los valores de NaN tendriamos que tomar la decisión si los dropeamos o tratamos de calcular un precio promedio en base a la cantidad de metros cuadrados.
# Out:
# (4138, 13)
#        property_type        place_name      price currency  \
# 52238          house         Caballito        NaN      NaN
# 91633      apartment          Belgrano  9627039.0      ARS
# 357        apartment          Paternal  1361745.0      ARS
# 13583      apartment              Once  1561500.0      ARS
# 31424      apartment  Villa del Parque        NaN      NaN
# 121005     apartment          Belgrano        NaN      NaN
# 27595          store          Belgrano        NaN      NaN
# 14728      apartment     Puerto Madero        NaN      NaN
# 118300     apartment             Nuñez        NaN      NaN
# 1886           house         Caballito        NaN      NaN
#
#         price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# 52238                          NaN              NaN                  NaN
# 91633                   9526613.85        539919.74                150.0
# 357                     1347539.75         76371.66                 32.0
# 13583                   1545211.08         87574.66                  NaN
# 31424                          NaN              NaN                192.0
# 121005                         NaN              NaN                 71.0
# 27595                          NaN              NaN                300.0
# 14728                          NaN              NaN                  NaN
# 118300                         NaN              NaN                 57.0
# 1886                           NaN              NaN                110.0
#
#         surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  rooms  \
# 52238                     NaN               NaN           NaN    NaN    4.0
# 91633                   118.0       3599.464933  81585.076271    NaN    NaN
# 357                      32.0       2386.614375  42554.531250    9.0    NaN
# 13583                    59.0               NaN  26466.101695    NaN    1.0
# 31424                    62.0               NaN           NaN    NaN    3.0
# 121005                   66.0               NaN           NaN    NaN    NaN
# 27595                   300.0               NaN           NaN    NaN    NaN
# 14728                     NaN               NaN           NaN    NaN    3.0
# 118300                   48.0               NaN           NaN    NaN    NaN
# 1886                     67.0               NaN           NaN    NaN    NaN
#
#                                               description
# 52238   Corredor Responsable: Pablo Di Girolamo - CDCP...
# 91633   El emprendimiento tiene unidades entre mediane...
# 357     Venta de Departamento 1 AMBIENTE en PaternalEl...
# 13583   Departamento ideal para estudiantesPrimer Piso...
# 31424   Venta de Departamento 3 AMBIENTES CON PATIO Y ...
# 121005  Torre de 16º pisos ubicado en pleno centro com...
# 27595   CONTACTO MARTIN PINUS 15 "importante local sob...
# 14728   Corredor Responsable: Mónica Silvia Martinuzzi...
# 118300  Excelente edificio con detalles de diseño, ubi...
# 1886                                 RESERVADA!!!!!!!!!!!

# %%
data_caba_clean.shape
# Out:
# (31019, 13)

# %% [markdown]
# <h3> Eliminamos registros según un umbral de datos faltantes </h3>
#
# [volver a TOC](#section_toc)

# %%
# Elimino primero los registros donde no tengo nada de informacion. 

umbral = 10
data_caba_clean.dropna(axis = 0, thresh=umbral, inplace=True)
# OJO que utilizando umbral de 10 se fueron casi 10000 datos incompletos. 
#--> se pierden 6000 datos aprox (ver shape de abajo), un 20% de los datos aprox

# Vuelvo a ver como quedaron los datos
mask_price_validation = data_caba_clean.price != data_caba_clean.price_aprox_usd
display(data_caba_clean.loc[mask_price_validation, :].shape)

display(data_caba_clean.shape)
# display(data_caba_clean.loc[mask_price_validation, :].head(30))
data_caba_clean.sample(5)
# Out:
# (1131, 13)
# (25627, 13)
#        property_type        place_name     price currency  \
# 90496      apartment      Barrio Norte  138000.0      USD
# 32263      apartment     Villa Ortuzar  107000.0      USD
# 112622     apartment        Villa Luro  118000.0      USD
# 35249             PH  Villa Santa Rita  156000.0      USD
# 85875      apartment          Belgrano  109000.0      USD
#
#         price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# 90496                    2434941.0         138000.0                 55.0
# 32263                    1887961.5         107000.0                 42.0
# 112622                   2082051.0         118000.0                 56.0
# 35249                    2752542.0         156000.0                104.0
# 85875                    1923250.5         109000.0                 46.0
#
#         surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  rooms  \
# 90496                    55.0       2509.090909   2509.090909    NaN    NaN
# 32263                    36.0       2547.619048   2972.222222    NaN    NaN
# 112622                   51.0       2107.142857   2313.725490    NaN    NaN
# 35249                    67.0       1500.000000   2328.358209    NaN    3.0
# 85875                    46.0       2369.565217   2369.565217    NaN    NaN
#
#                                               description
# 90496   Excelente departamento. Muy luminoso. Living c...
# 32263   CODIGO: 1974-620 ubicado en: Balbin 2300 -  Pu...
# 112622  Venta departamento de 2 ambientes con Balcón T...
# 35249   PH / departamento tipo casa por pasillo en dos...
# 85875   UNIDAD A ESTRENAR en el PISO 13, de 46,45m2, c...

# %%
# Para la superficie de metros cuadadros totales, podemos creer que en caso de ser Nan 
#es porque es un departamente sin balcon y la cantidad de m2 cubierta sería iguala la cantidad de m2 totales.data_caba

data_caba_clean.surface_total_in_m2.fillna(data_caba_clean.surface_covered_in_m2 + (data_caba_clean.surface_covered_in_m2 * 0.10), inplace=True)

data_caba_clean.sample(5)
# Out:
#       property_type        place_name     price currency  \
# 38043     apartment         Monserrat  140000.0      USD
# 85790         store      Villa Devoto  350000.0      USD
# 87566     apartment  Parque Patricios  107540.0      USD
# 96982     apartment           Palermo  270000.0      USD
# 93393     apartment            Flores  376004.0      USD
#
#        price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# 38043                  2470230.00         140000.0                 75.0
# 85790                  6175575.00         350000.0                300.0
# 87566                  1897489.53         107540.0                 56.0
# 96982                  4764015.00         270000.0                 66.0
# 93393                  6634402.57         376004.0                192.0
#
#        surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  rooms  \
# 38043                   75.0       1866.666667   1866.666667    NaN    3.0
# 85790                  220.0       1166.666667   1590.909091    NaN    NaN
# 87566                   47.0       1920.357143   2288.085106    NaN    NaN
# 96982                   66.0       4090.909091   4090.909091    NaN    NaN
# 93393                  119.0       1958.354167   3159.697479    NaN    NaN
#
#                                              description
# 38043  VENTA DEPARTAMENTO 3 AMBIENTES MONTSERRAT. REC...
# 85790  VENTA EN BLOCK: 2 locales comerciales + 3 depa...
# 87566  Espai Patricios se encuentra emplazado en el B...
# 96982  Divino departamento en torre. Totalmente recic...
# 93393  Unidad de 3 dormitorios grandes. Una suite pri...

# %% [markdown]
# <h3> Completamos datos faltantes de superficie </h3>
#
# [volver a TOC](#section_toc)

# %%
# Idem al punto anterior pero ahora de surface_total a surface_covered

data_caba_clean.surface_covered_in_m2.fillna(data_caba_clean.surface_total_in_m2, inplace=True)

data_caba_clean.sample(5)
# Out:
#        property_type    place_name     price currency  \
# 12667          house  Villa Crespo  795000.0      USD
# 114086     apartment  Barrio Norte  350000.0      USD
# 80281      apartment      Recoleta  470000.0      USD
# 13244      apartment  Villa Crespo  123700.0      USD
# 59977      apartment       Palermo  730000.0      USD
#
#         price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# 12667                  14027377.50         795000.0                342.1
# 114086                  6175575.00         350000.0                119.0
# 80281                   8292915.00         470000.0                148.0
# 13244                   2182624.65         123700.0                 57.2
# 59977                  12880485.00         730000.0                155.0
#
#         surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  rooms  \
# 12667                   311.0               NaN   2556.270096    NaN    8.0
# 114086                   88.0       2941.176471   3977.272727    NaN    4.0
# 80281                   138.0       3175.675676   3405.797101    NaN    NaN
# 13244                    52.0               NaN   2378.846154    NaN    3.0
# 59977                   140.0       4709.677419   5214.285714    NaN    4.0
#
#                                               description
# 12667   Corredor Responsable: Veronica Grela Reina - C...
# 114086  Edificio clásico. Depto con palier privado.GRA...
# 80281   Importante semipiso de 148m2 totales (138 cubi...
# 13244   Corredor Responsable: Pamela Suarez - CUCICBA ...
# 59977   CONTACTO LEONEL 15  ***LAFINUR WHITE TOWER*** ...

# %% [markdown]
# <h3> Completamos datos faltantes de price_usd_per_m2 </h3>
#
# [volver a TOC](#section_toc)

# %%
# Idem al punto anterior pero ahora calculamos el precio por metro cuadrado.

data_caba_clean.price_usd_per_m2.fillna(data_caba_clean.price_aprox_usd / data_caba_clean.surface_total_in_m2, inplace=True)

data_caba_clean.sample(5)
# Out:
#        property_type     place_name     price currency  \
# 87901      apartment      Chacarita  110295.0      USD
# 119119         house       Belgrano  695000.0      USD
# 17868      apartment           Boca  128000.0      USD
# 119800     apartment  Palermo Chico  345000.0      USD
# 56591      apartment     Colegiales  325000.0      USD
#
#         price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# 87901                   1946100.12         110295.0                 51.0
# 119119                 12262927.50         695000.0                463.0
# 17868                   2258496.00         128000.0                107.0
# 119800                  6087352.50         345000.0                 80.0
# 56591                   5734462.50         325000.0                103.4
#
#         surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  rooms  \
# 87901                    48.0       2162.647059   2297.812500    NaN    NaN
# 119119                  235.0       1501.079914   2957.446809    NaN    NaN
# 17868                    80.0       1196.261682   1600.000000    NaN    4.0
# 119800                   80.0       4312.500000   4312.500000    NaN    3.0
# 56591                    94.0       3143.133462   3457.446809    4.0    3.0
#
#                                               description
# 87901   Entrega Marzo 2019Forma de pago 50% y 22 cuota...
# 119119  Venta de Casa 5 AMBIENTES en Belgrano, Capital...
# 17868   Venta de Departamento 4 AMBIENTES en Boca, Cap...
# 119800  EXCELENTE SEMIPISO-PALIER PRIVADOR- LIVING COM...
# 56591   Corredor Responsable: Uno Bienes Raices SRL - ...

# %% [markdown]
# <h3> Eliminamos floor </h3>
#
# [volver a TOC](#section_toc)

# %%
display(data_caba.floor.isnull().count())

# El piso es un dato muy incompleto por lo que se dropea

# Dropeamos la columna creada anteriormente.
data_caba_clean.drop(columns=['floor'], inplace=True)

# En el caso de Rooms lo reemplazamos por 0 --> Lo pasé más abajo
# data_caba_clean.rooms.fillna(0, inplace=True)
# Out:
# 32316

# %%
display(data_caba.rooms.count())
# En el caso de rooms, podemos tomar que el dato para los NaN es 0?? modifica esto el analisis para predecir?
# Out:
# 15325

# %% [markdown]
# <h3> Eliminamos columnas de precios en moneda local </h3>
#
# [volver a TOC](#section_toc)

# %%
# Dropeamos los valores que sabemos que está repetidos o con otra moneda.data_caba

data_caba_clean.drop(columns=['price', 'currency','price_per_m2', 'price_aprox_local_currency'], inplace=True)

data_caba_clean.sample(20)
# Out:
#        property_type        place_name  price_aprox_usd  surface_total_in_m2  \
# 36207      apartment           Coghlan         448000.0                137.5
# 73376      apartment         Balvanera         139000.0                132.0
# 19705      apartment     Villa Urquiza         980000.0                323.4
# 107048     apartment      Palermo Soho         502200.0                107.0
# 36681      apartment             Nuñez         138500.0                 50.0
# 87251      apartment              Boca          95000.0                 77.0
# 48861      apartment          Belgrano         108000.0                 33.0
# 96837      apartment         Caballito          90000.0                 35.0
# 86701      apartment      Villa Crespo          82000.0                 39.0
# 10930             PH        Villa Luro         319000.0                170.5
# 26767      apartment             Boedo         566800.0                 31.0
# 97704      apartment           Palermo         179000.0                 79.0
# 95228      apartment     Villa Urquiza          80953.0                 36.0
# 36989      apartment  Parque Patricios          99000.0                 59.0
# 25964      apartment           Almagro         678200.0                 43.0
# 72480      apartment          Saavedra         175000.0                 70.0
# 105910     apartment           Palermo         585000.0                177.0
# 50791          house          Belgrano         895000.0                330.0
# 37155      apartment      Barrio Norte         346000.0                121.0
# 60242          house  Parque Patricios         160000.0                101.2
#
#         surface_covered_in_m2  price_usd_per_m2  rooms  \
# 36207                   125.0       3258.181818    2.0
# 73376                   110.0       1053.030303    NaN
# 19705                   294.0       3030.303030    6.0
# 107048                  104.0       4693.457944    NaN
# 36681                    46.0       2770.000000    NaN
# 87251                    50.0       1233.766234    NaN
# 48861                    30.0       3272.727273    1.0
# 96837                    33.0       2571.428571    NaN
# 86701                    34.0       2102.564103    NaN
# 10930                   155.0       1870.967742    5.0
# 26767                    31.0      18283.870968    1.0
# 97704                    64.0       2265.822785    NaN
# 95228                    36.0       2248.694444    NaN
# 36989                    56.0       1677.966102    3.0
# 25964                    43.0      15772.093023    2.0
# 72480                    61.0       2500.000000    NaN
# 105910                  177.0       3305.084746    NaN
# 50791                   300.0       2712.121212    5.0
# 37155                   118.0       2859.504132    NaN
# 60242                    92.0       1581.027668    4.0
#
#                                               description
# 36207   Corredor Responsable: Gustavo Guastello - C.U....
# 73376   VENTA DEPARTAMENTO DE 3 AMBIENTES CON DEPENDEN...
# 19705   Corredor Responsable: Raul Hector Merlo - CUCI...
# 107048  CODIGO: 1237-79 ubicado en: Paraguay 4700 -  P...
# 36681   En VENTA en NUÑEZ2 AMB con BALCON Al frente-Mu...
# 87251   Di Mitrio Inmobiliaria promueve y comercializa...
# 48861   PISO 2° "E". Gran Ambiente, con Balcón !!! Súp...
# 96837   IMPECABLE MONOAMBIENTE, MUY LUMMINOSO A METROS...
# 86701   VENTA EN POZO - UNIDADES DE 1 Y 2 AMBIENTESDep...
# 10930   Corredor Responsable: Raul Hector Merlo - CUCI...
# 26767   Depto financiado en 58 meses en pesosPequeo an...
# 97704   Encantador departamento semipiso de tres ambie...
# 95228   Presentamos Star Álvarez Thomas,una torre resi...
# 36989   IMPECABLE, 3 ambientes en piso alto.Torre de M...
# 25964   lan832- VENDO EN BOEDO - VIVIENDA O INVERSIOND...
# 72480            DEPARTAMENTO  2 AMBIENTES VENTA SAAVEDRA
# 105910              Excelente PISO con 2 cocheras Fija...
# 50791   Corredor Responsable: Rebeca Stern - C.U.C.I.C...
# 37155   CODIGO: 572-2904 ubicado en: Arenales 2904 -  ...
# 60242   Casa 4 amb. Ingresando nos encontramos con un ...

# %% [markdown]
# <h3> Nuevo recuento de nulos </h3>

# %%
print('\nPorcentaje de valores incompletos por columna:')
print(f'{round(100 * data_caba_clean.isnull().sum()/data_caba_clean.shape[0], 2)}')

display(data_caba_clean.shape)
# Out:
# Porcentaje de valores incompletos por columna:
# property_type             0.00
# place_name                0.00
# price_aprox_usd           0.00
# surface_total_in_m2       0.00
# surface_covered_in_m2     0.00
# price_usd_per_m2          0.00
# rooms                    43.82
# description               0.00
# dtype: float64
# (25627, 8)

# %% [markdown]
# <h3>Creación de una columna para categorizar por metros cuadrados

# %%
# Delimitamos los bins para realizar un cut
# bins = [20, 30, 45, 75, 150, 220]
bins = [0, 30, 45, 75, 150, 220]
labels = ['mono', 's45', 's75', 's150', 'm220' ]

data_caba_clean['m2_categories'] = pd.cut(data_caba_clean.surface_covered_in_m2, bins, labels)
data_caba_clean['m2_labels'] = pd.cut(x=data_caba_clean.surface_covered_in_m2, bins=bins, labels=labels, right=False)

# %%
data_caba_clean.m2_categories.value_counts().sort_index()
# Out:
# (0, 30]       2530
# (30, 45]      7452
# (45, 75]      7227
# (75, 150]     5449
# (150, 220]    1572
# Name: m2_categories, dtype: int64

# %%
data_caba_clean.m2_labels.value_counts().sort_index()
# Out:
# mono    1633
# s45     7863
# s75     7475
# s150    5574
# m220    1628
# Name: m2_labels, dtype: int64

# %% [markdown]
# <a id="section_caba_description"></a>
# <h3> Análisis del campo <strong>description</strong></h3>
#
# [volver a TOC](#section_toc)

# %% [markdown]
# Normalización del campo, todo minuscula, sin tildes, etc

# %%
data_caba_clean.description = data_caba_clean.description.str.lower()

data_caba_clean.description.sample(10)
# Out:
# 63922    corredor responsable: gustavo guastello - c.u....
# 5666     duplex de 2 ambientes al frente que se desarro...
# 26478    es un depto 2 amb frente a estrenar con balcon...
# 9981     departamento monoambiente al frente con salida...
# 85473    departamento en venta de cuatro ambientes en e...
# 29164    contacto florencia 15 oro park toweroro y cerv...
# 26293    sj146- las monedas cambian, los ladrillos qued...
# 21778    venta de departamento, monoambiente divisible ...
# 27347    corredor responsable: ariel champanier - c.u.c...
# 24742    excelente 4 ambientes con dependencia en barri...
# Name: description, dtype: object

# %% [markdown]
# <a id="section_caba_description_amb"></a>
# <h4> Cantidad de ambientes</h4>
#
# [volver a TOC](#section_toc)

# %%
amb_pattern = "((?P<numero_amb>\d)(\s)?(amb|anv|amv|anb))"
amb_pattern_regex = re.compile(amb_pattern)

# %%
amb_match = data_caba_clean.description.apply(lambda x: x if (x is np.NaN) | (x is None) else\
                                      amb_pattern_regex.search(x))
mask_amb_match_notnull = amb_match.notnull()

# Aplicamos el grupo que encuentra el dígito de cantidad de ambientes, casteado como integer
data_caba_clean.loc[mask_amb_match_notnull, 'number_rooms'] = \
amb_match.loc[mask_amb_match_notnull].apply(lambda x: int(x.group("numero_amb")))

# %%
dorm_pattern = "((?P<numero_dorm>\d)(\s)?(dorm))"
dorm_pattern_regex = re.compile(dorm_pattern)

# %%
dorm_match = data_caba_clean.description.apply(lambda x: x if (x is np.NaN) | (x is None) else dorm_pattern_regex.search(x))

mask_dorm_match_notnull = dorm_match.notnull()

data_caba_clean.loc[mask_dorm_match_notnull, 'number_rooms'] = \
dorm_match.loc[mask_dorm_match_notnull].apply(lambda x: int(x.group("numero_dorm"))+1)

#se asume que el numero de ambientes es numero_dorm +1

# %% [markdown]
# Tratamos de llenar los rooms que faltan con lo que obtuvimos de la descripción

# %%
data_caba_clean.head(3)
# Out:
#   property_type place_name  price_aprox_usd  surface_total_in_m2  \
# 0            PH  Mataderos          62000.0                 55.0
# 2     apartment  Mataderos          72000.0                 55.0
# 7     apartment   Belgrano         138000.0                 45.0
#
#    surface_covered_in_m2  price_usd_per_m2  rooms  \
# 0                   40.0       1127.272727    NaN
# 2                   55.0       1309.090909    NaN
# 7                   40.0       3066.666667    NaN
#
#                                          description m2_categories m2_labels  \
# 0  2 ambientes tipo casa planta baja por pasillo,...      (30, 45]       s45
# 2  2 ambientes 3er piso lateral living comedor am...      (45, 75]       s75
# 7  excelente monoambiente a estrenar amplio super...      (30, 45]       s45
#
#    number_rooms
# 0           2.0
# 2           2.0
# 7           NaN

# %%
data_caba_clean.rooms.isnull().sum()
# Out:
# 11230

# %%
data_caba_clean.number_rooms.isnull().sum()
# Out:
# 9881

# %%
data_caba_clean.rooms.fillna(data_caba_clean.number_rooms, inplace=True)

# %%
data_caba_clean.rooms.isnull().sum()
# Out:
# 4665

# %%
# data_caba_clean.rooms.fillna(0, inplace=True)
# completar con los datos de categorias

# %%
data_caba_clean.rooms.value_counts()
# Out:
# 2.0     5406
# 3.0     5262
# 1.0     4341
# 4.0     4012
# 5.0     1266
# 6.0      362
# 7.0      174
# 8.0       57
# 9.0       27
# 10.0      24
# 12.0      11
# 11.0       9
# 0.0        4
# 17.0       3
# 22.0       1
# 15.0       1
# 14.0       1
# 13.0       1
# Name: rooms, dtype: int64

# %%
rooms_dict = {
"mono": 1, "s45":  2, "s75":  3, "s150":  4, "m220": 5}

data_caba_clean["rooms_upon_categories"] = data_caba_clean.m2_labels.map(rooms_dict)
data_caba_clean['rooms_upon_categories']

data_caba_clean.rooms.fillna(data_caba_clean.rooms_upon_categories, inplace=True)
data_caba_clean.rooms.isnull().sum()
# Out:
# 763

# %% [markdown]
# ### Llenamos los que faltan según las categorías de los bins???
# Además: eliminar los que tengan más de 10 ambientes? Son pocos datos!

# %% [markdown]
# <a id="section_caba_description_amb"></a>
# <h4> Amenities</h4>
#
# [volver a TOC](#section_toc)

# %% [markdown]
# <h5> Pileta </h5>

# %%
pileta_pattern = "(?P<pileta>pileta|piscina|picina|pisina|pool)"
pileta_pattern_regex = re.compile(pileta_pattern)

# %%
pileta_match = data_caba_clean.description.apply(lambda x: x if (x is np.NaN) | (x is None) else\
                                      pileta_pattern_regex.search(x))
mask_pileta_match_notnull = pileta_match.notnull()

data_caba_clean.loc[mask_pileta_match_notnull, 'pool'] = 1

# %%
# data_caba_clean['pool']

# %%
data_caba_clean['pool'].notnull().sum()
# Out:
# 6161

# %%
#Completamos los datos NaN con ceros (convertimos en una variable dummy)
data_caba_clean.pool.fillna(0, inplace = True)

# %% [markdown]
# <h5> Laundry </h5>

# %%
laudry_pattern = "(?P<laundry>laundry|lavadero)"
laundry_pattern_regex = re.compile(laudry_pattern)

laundry_match = data_caba_clean.description.apply(lambda x: x if (x is np.NaN) | (x is None) else\
                                      laundry_pattern_regex.search(x))
mask_laundry_match_notnull = laundry_match.notnull()

data_caba_clean.loc[mask_laundry_match_notnull, 'laundry'] = 1

# %%
data_caba_clean['laundry'].notnull().sum()
# Out:
# 10958

# %%
data_caba_clean.laundry.fillna(0, inplace = True)

# %% [markdown]
# <h5> Parking </h5>

# %%
parking_pattern = "(?P<parking>parking|estacionamiento|garage|cochera|garaje)"
parking_pattern_regex = re.compile(parking_pattern)

parking_match = data_caba_clean.description.apply(lambda x: x if (x is np.NaN) | (x is None) else\
                                      parking_pattern_regex.search(x))
mask_parking_match_notnull = parking_match.notnull()

data_caba_clean.loc[mask_parking_match_notnull, 'parking'] = 1

# %%
data_caba_clean['parking'].notnull().sum()
# Out:
# 9796

# %%
data_caba_clean.parking.fillna(0, inplace = True)

# %% [markdown]
# <h5> Gimnasio </h5>

# %%
gym_pattern = "(?P<gimnasio>gim|gym|fitness|fitnes|ejercicio)"
gym_pattern_regex = re.compile(gym_pattern)

gym_match = data_caba_clean.description.apply(lambda x: x if (x is np.NaN) | (x is None) else\
                                      gym_pattern_regex.search(x))
mask_gim_match_notnull = gym_match.notnull()

data_caba_clean.loc[mask_gim_match_notnull, 'gym'] = 1

# %%
data_caba_clean['gym'].notnull().sum()
# Out:
# 3363

# %%
data_caba_clean.gym.fillna(0, inplace = True)

# %%
# plt.figure(figsize=(13,10))
# sns.heatmap(data_caba_clean.corr(),annot=True)
# plt.title("Correlation Heatmap")
# plt.show()

# %% [markdown]
# <a id="section_caba_dummies"></a>
# <h3> Creación dummies sobre datos categóricos </h3>
#
# [volver a TOC](#section_toc)

# %%
# Usamos la función get_dummies con one-hot encoding (drop_first=True)
property_type_dummies = pd.get_dummies(data_caba_clean['property_type'], drop_first = True, prefix='prop_type')
property_type_dummies
# Out:
#         prop_type_apartment  prop_type_house  prop_type_store
# 0                         0                0                0
# 2                         1                0                0
# 7                         1                0                0
# 8                         1                0                0
# 13                        1                0                0
# ...                     ...              ...              ...
# 121153                    1                0                0
# 121157                    1                0                0
# 121158                    1                0                0
# 121215                    1                0                0
# 121217                    1                0                0
#
# [25627 rows x 3 columns]

# %%
m2_labels_dummies = pd.get_dummies(data_caba_clean['m2_labels'], drop_first = True, prefix='m2_label')

# %%
place_name_dummies = pd.get_dummies(data_caba_clean['place_name'], drop_first = True, prefix='place_name')

# %%
# Hacemos un join para concatenar las columnas al dataframe
data_caba_clean = data_caba_clean.join([property_type_dummies,m2_labels_dummies, place_name_dummies])

# %%
data_caba_clean.head(3)
# Out:
#   property_type place_name  price_aprox_usd  surface_total_in_m2  \
# 0            PH  Mataderos          62000.0                 55.0
# 2     apartment  Mataderos          72000.0                 55.0
# 7     apartment   Belgrano         138000.0                 45.0
#
#    surface_covered_in_m2  price_usd_per_m2 rooms  \
# 0                   40.0       1127.272727     2
# 2                   55.0       1309.090909     2
# 7                   40.0       3066.666667     2
#
#                                          description m2_categories m2_labels  \
# 0  2 ambientes tipo casa planta baja por pasillo,...      (30, 45]       s45
# 2  2 ambientes 3er piso lateral living comedor am...      (45, 75]       s75
# 7  excelente monoambiente a estrenar amplio super...      (30, 45]       s45
#
#    number_rooms rooms_upon_categories  pool  laundry  parking  gym  \
# 0           2.0                     2   0.0      1.0      0.0  0.0
# 2           2.0                     3   0.0      1.0      0.0  0.0
# 7           NaN                     2   1.0      1.0      0.0  0.0
#
#    prop_type_apartment  prop_type_house  prop_type_store  m2_label_s45  \
# 0                    0                0                0             1
# 2                    1                0                0             0
# 7                    1                0                0             1
#
#    m2_label_s75  m2_label_s150  m2_label_m220  place_name_Agronomía  \
# 0             0              0              0                     0
# 2             1              0              0                     0
# 7             0              0              0                     0
#
#    place_name_Almagro  place_name_Balvanera  place_name_Barracas  \
# 0                   0                     0                    0
# 2                   0                     0                    0
# 7                   0                     0                    0
#
#    place_name_Barrio Norte  place_name_Belgrano  place_name_Boca  \
# 0                        0                    0                0
# 2                        0                    0                0
# 7                        0                    1                0
#
#    place_name_Boedo  place_name_Caballito  place_name_Catalinas  \
# 0                 0                     0                     0
# 2                 0                     0                     0
# 7                 0                     0                     0
#
#    place_name_Centro / Microcentro  place_name_Chacarita  place_name_Coghlan  \
# 0                                0                     0                   0
# 2                                0                     0                   0
# 7                                0                     0                   0
#
#    place_name_Colegiales  place_name_Congreso  place_name_Constitución  \
# 0                      0                    0                        0
# 2                      0                    0                        0
# 7                      0                    0                        0
#
#    place_name_Flores  place_name_Floresta  place_name_Las Cañitas  \
# 0                  0                    0                       0
# 2                  0                    0                       0
# 7                  0                    0                       0
#
#    place_name_Liniers  place_name_Mataderos  place_name_Monserrat  \
# 0                   0                     1                     0
# 2                   0                     1                     0
# 7                   0                     0                     0
#
#    place_name_Monte Castro  place_name_Nuñez  place_name_Once  \
# 0                        0                 0                0
# 2                        0                 0                0
# 7                        0                 0                0
#
#    place_name_Palermo  place_name_Palermo Chico  place_name_Palermo Hollywood  \
# 0                   0                         0                             0
# 2                   0                         0                             0
# 7                   0                         0                             0
#
#    place_name_Palermo Soho  place_name_Palermo Viejo  \
# 0                        0                         0
# 2                        0                         0
# 7                        0                         0
#
#    place_name_Parque Avellaneda  place_name_Parque Centenario  \
# 0                             0                             0
# 2                             0                             0
# 7                             0                             0
#
#    place_name_Parque Chacabuco  place_name_Parque Chas  \
# 0                            0                       0
# 2                            0                       0
# 7                            0                       0
#
#    place_name_Parque Patricios  place_name_Paternal  place_name_Pompeya  \
# 0                            0                    0                   0
# 2                            0                    0                   0
# 7                            0                    0                   0
#
#    place_name_Puerto Madero  place_name_Recoleta  place_name_Retiro  \
# 0                         0                    0                  0
# 2                         0                    0                  0
# 7                         0                    0                  0
#
#    place_name_Saavedra  place_name_San Cristobal  place_name_San Nicolás  \
# 0                    0                         0                       0
# 2                    0                         0                       0
# 7                    0                         0                       0
#
#    place_name_San Telmo  place_name_Tribunales  place_name_Velez Sarsfield  \
# 0                     0                      0                           0
# 2                     0                      0                           0
# 7                     0                      0                           0
#
#    place_name_Versalles  place_name_Villa Crespo  place_name_Villa Devoto  \
# 0                     0                        0                        0
# 2                     0                        0                        0
# 7                     0                        0                        0
#
#    place_name_Villa General Mitre  place_name_Villa Lugano  \
# 0                               0                        0
# 2                               0                        0
# 7                               0                        0
#
#    place_name_Villa Luro  place_name_Villa Ortuzar  \
# 0                      0                         0
# 2                      0                         0
# 7                      0                         0
#
#    place_name_Villa Pueyrredón  place_name_Villa Real  \
# 0                            0                      0
# 2                            0                      0
# 7                            0                      0
#
#    place_name_Villa Riachuelo  place_name_Villa Santa Rita  \
# 0                           0                            0
# 2                           0                            0
# 7                           0                            0
#
#    place_name_Villa Soldati  place_name_Villa Urquiza  \
# 0                         0                         0
# 2                         0                         0
# 7                         0                         0
#
#    place_name_Villa del Parque
# 0                            0
# 2                            0
# 7                            0

# %% [markdown]
# ### Falta reindexar las filas.

# %% [markdown]
# ### Falta el dummy de Rooms pero primero hay que ver si completamos los datos con la info de los bins

# %%
# Exportamos el archivo para usar en otras notebooks, esto lo guarda en el mismo directorio en el que estamos operando
# data_caba_clean.to_csv('data_caba_clean.csv')

# %%
from sklearn.model_selection import cross_val_score, train_test_split, KFold
from sklearn.linear_model import LinearRegression
from sklearn import metrics, linear_model

# %% [markdown]
# 1. Primer modelo
# Eliminar rooms nulos
# Modelar
#
# 2. Imputar datos faltantes en los rooms
# modelar
#
# 3. Eliminar outliers
# modelar

# %%
# Funcion para realizar el entrenamiento pero con un set de testeo.

def graf_lineal_model(X, y, y_pred):
    # Graficamos el modelo
    plt.scatter(y_pred, y, s=30, c='b', alpha=0.4)
    plt.plot(y,y, '-.',c='g')
    plt.show()
    print(y.shape)
    print(y_pred.shape)
    return

def train_test_error(feature_cols, target):
    X = data_caba_clean[feature_cols]
    y = data_caba_clean[target].values.ravel()
    
    # OJO que no trabajamos con tiempo por lo tanto debe ser shuffle=True.
    X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=10)
    
    linreg = LinearRegression()
    linreg.fit(X_train, y_train)
    y_pred = linreg.predict(X_test)
    
#    print (feature_cols)
#    print ("y_test sample: ",y_test.values[0:10])
#     print ("y_test sample: ",y_test)
#    print ("y_pred sample: ",y_pred[0:20].astype(int))
#    print ('MAE:', metrics.mean_absolute_error(y_test, y_pred))
#    print ('MSE:', metrics.mean_squared_error(y_test, y_pred))
    print ('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
    print ('R2:', metrics.r2_score(y_test, y_pred))
    graf_lineal_model(X, y_test, y_pred)
    return 

def train_test_error_lazzo(feature_cols, target):
    X = data_caba_clean[feature_cols]
    y = data_caba_clean[target].values.ravel()
#     cv = KFold(5, shuffle=True)
    cv = 3
    # OJO que no trabajamos con tiempo por lo tanto debe ser shuffle=True.
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10)
    
    model = linear_model.LassoCV(alphas=np.linspace(0.00001,0.1, 1000), normalize=True).fit(X_train, y_train)
    scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='r2')
    
    y_pred = model.predict(X_train)
    print(dict(alpha=model.alpha_, scores=scores, mean_score=scores.mean(), zero_coefs=(model.coef_ == 0).sum()))
    print ("r^2:", model.score(X, y))
    print ("Imprime Alpha", model.alpha_)
    graf_lineal_model(X, y_train, y_pred)
    return 

def train_test_error_ridge(feature_cols, target):
    X = data_caba_clean[feature_cols]
    y = data_caba_clean[target].values.ravel()
#     cv = KFold(5, shuffle=True)
    cv = 3
    # OJO que no trabajamos con tiempo por lo tanto debe ser shuffle=True.
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10)
    
    #model = linear_model.Ridge(alpha=0.5, normalize=True).fit(X_train, y_train)
    model = linear_model.RidgeCV(alphas=np.linspace(0.00001,0.1, 1000), normalize=True).fit(X_train, y_train)#agr
    
    scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='r2')
    
    y_pred = model.predict(X_train)
    print(dict(alpha=model.alpha_, scores=scores, mean_score=scores.mean(), zero_coefs=(model.coef_ == 0).sum()))
    print ("r^2:", model.score(X, y))
    print ("Coeficientes de la regresión", model.coef_)
    graf_lineal_model(X, y_train, y_pred)
    return 

def train_test_error_elastic(feature_cols, target):
    X = data_caba_clean[feature_cols]
    y = data_caba_clean[target].values.ravel()
#     cv = KFold(5, shuffle=True)
    cv = 3
    # OJO que no trabajamos con tiempo por lo tanto debe ser shuffle=True.
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10)
    
    model = linear_model.ElasticNetCV(alphas=np.linspace(0.00001,0.1, 1000), normalize=True).fit(X_train, y_train)
    
    scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='r2')
    
    y_pred = model.predict(X_train)
    print(dict(alpha=model.alpha_, scores=scores, mean_score=scores.mean(), zero_coefs=(model.coef_ == 0).sum()))
    print ("r^2:", model.score(X, y))
    print ("Coeficientes de la regresión", model.coef_)
    graf_lineal_model(X, y_train, y_pred)
    return

# %%
display(data_caba_clean.columns)
# Out:
# Index(['property_type', 'place_name', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'rooms', 'description',
#        'm2_categories', 'm2_labels', 'number_rooms', 'rooms_upon_categories',
#        'pool', 'laundry', 'parking', 'gym', 'prop_type_apartment',
#        'prop_type_house', 'prop_type_store', 'm2_label_s45', 'm2_label_s75',
#        'm2_label_s150', 'm2_label_m220', 'place_name_Agronomía',
#        'place_name_Almagro', 'place_name_Balvanera', 'place_name_Barracas',
#        'place_name_Barrio Norte', 'place_name_Belgrano', 'place_name_Boca',
#        'place_name_Boedo', 'place_name_Caballito', 'place_name_Catalinas',
#        'place_name_Centro / Microcentro', 'place_name_Chacarita',
#        'place_name_Coghlan', 'place_name_Colegiales', 'place_name_Congreso',
#        'place_name_Constitución', 'place_name_Flores', 'place_name_Floresta',
#        'place_name_Las Cañitas', 'place_name_Liniers', 'place_name_Mataderos',
#        'place_name_Monserrat', 'place_name_Monte Castro', 'place_name_Nuñez',
#        'place_name_Once', 'place_name_Palermo', 'place_name_Palermo Chico',
#        'place_name_Palermo Hollywood', 'place_name_Palermo Soho',
#        'place_name_Palermo Viejo', 'place_name_Parque Avellaneda',
#        'place_name_Parque Centenario', 'place_name_Parque Chacabuco',
#        'place_name_Parque Chas', 'place_name_Parque Patricios',
#        'place_name_Paternal', 'place_name_Pompeya', 'place_name_Puerto Madero',
#        'place_name_Recoleta', 'place_name_Retiro', 'place_name_Saavedra',
#        'place_name_San Cristobal', 'place_name_San Nicolás',
#        'place_name_San Telmo', 'place_name_Tribunales',
#        'place_name_Velez Sarsfield', 'place_name_Versalles',
#        'place_name_Villa Crespo', 'place_name_Villa Devoto',
#        'place_name_Villa General Mitre', 'place_name_Villa Lugano',
#        'place_name_Villa Luro', 'place_name_Villa Ortuzar',
#        'place_name_Villa Pueyrredón', 'place_name_Villa Real',
#        'place_name_Villa Riachuelo', 'place_name_Villa Santa Rita',
#        'place_name_Villa Soldati', 'place_name_Villa Urquiza',
#        'place_name_Villa del Parque'],
#       dtype='object')

# %%
# Regresion lineal Simple

feature_cols = ['price_aprox_usd']
target = ['price_usd_per_m2']

train_test_error(feature_cols, target)
# Out:
# RMSE: 29676.697503514544
# R2: 0.0021623787501081626
# (6407,)
# (6407,)

# %%
feature_cols = ['surface_total_in_m2', 'price_aprox_usd', 'surface_covered_in_m2']
target = ['price_usd_per_m2']

train_test_error(feature_cols, target)
# Out:
# RMSE: 31351.431669950027
# R2: -0.11363658457882542
# (6407,)
# (6407,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2',
                'pool', 'laundry', 'parking', 'gym', 'place_name_Puerto Madero']
target = ['price_usd_per_m2']

train_test_error(feature_cols, target)
# Out:
# RMSE: 31303.053099118886
# R2: -0.1102023185675356
# (6407,)
# (6407,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2',
                'pool', 'laundry', 'parking', 'gym', 'place_name_Puerto Madero']
target = ['price_usd_per_m2']
train_test_error_lazzo(feature_cols, target)
# Out:
# {'alpha': 0.0636672972972973, 'scores': array([0.07533284, 0.19874048, 0.098415  ]), 'mean_score': 0.12416277591056779, 'zero_coefs': 0}
# r^2: -0.09324738755090678
# Imprime Alpha 0.0636672972972973
# (19220,)
# (19220,)

# %% [markdown]
# ## Recordar que hay variables ROOM es INT!!!!

# %%
feature_cols = ['surface_total_in_m2']
target = ['price_usd_per_m2']

train_test_error_lazzo(feature_cols, target)
# Out:
# {'alpha': 0.03874486486486487, 'scores': array([0.00356508, 0.00201259, 0.00311627]), 'mean_score': 0.0028979800710049832, 'zero_coefs': 0}
# r^2: -0.010591638526659786
# Imprime Alpha 0.03874486486486487
# (19220,)
# (19220,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2',
                'pool', 'laundry', 'parking', 'gym', 'place_name_Puerto Madero']
target = ['price_usd_per_m2']

train_test_error_lazzo(feature_cols, target)
# Out:
# {'alpha': 0.0636672972972973, 'scores': array([0.07533284, 0.19874048, 0.098415  ]), 'mean_score': 0.12416277591056779, 'zero_coefs': 0}
# r^2: -0.09324738755090678
# Imprime Alpha 0.0636672972972973
# (19220,)
# (19220,)

# %% [markdown]
# # Necesitamos definir Outliers.

# %%
fig, ax = plt.subplots()
bp = ax.boxplot(data_caba_clean['surface_covered_in_m2'].dropna(), vert=False, showmeans=True)

# %%
# Definimos outliers aproximados
lower_bound = 0.01
upper_bound = 0.96
rest = data_caba_clean.price_usd_per_m2.quantile([lower_bound, upper_bound])
rest
# Out:
# 0.01     760.226087
# 0.96    6899.555556
# Name: price_usd_per_m2, dtype: float64

# %%
# Creamos una mask entendiendo que los precios minimos y maximos pueden rondar los 600 USD y 4000 USD y fijamos outliers aproximados

precioxm2_mask = (data_caba_clean.price_usd_per_m2 >= rest[0.01]) & (data_caba_clean.price_usd_per_m2 <= rest[0.96])
data_caba_clean = data_caba_clean.loc[precioxm2_mask, :]

# Vuelvo a graficar.

plt.hist(data_caba_clean.price_usd_per_m2, bins=20, rwidth=0.8, color = '#29788E')
plt.xlabel = 'Precio x M2'
plt.ylabel = 'Count'
plt.show()

print(data_caba_clean.price_usd_per_m2.max()) 
print(data_caba_clean.price_usd_per_m2.min())

# Parece una distribución normal? sino fuera por los valores elevados que tenemos a partir de los 3500...
# Out:
# 6888.8888888888905
# 760.8695652173913

# %%
# Definimos outliers aproximados
lower_bound = 0.001
upper_bound = 0.99
rest = data_caba_clean.surface_covered_in_m2.quantile([lower_bound, upper_bound])
rest
# Out:
# 0.001     12.0
# 0.990    405.0
# Name: surface_covered_in_m2, dtype: float64

# %%
# Creamos una mask entendiendo que los precios minimos y maximos pueden rondar los 600 USD y 4000 USD y fijamos outliers aproximados

surface_xm2_mask = (data_caba_clean.surface_covered_in_m2 >= rest[0.001]) & (data_caba_clean.surface_covered_in_m2 <= rest[0.99])
data_caba_clean = data_caba_clean.loc[surface_xm2_mask, :]

# Vuelvo a graficar.

plt.hist(data_caba_clean.surface_covered_in_m2, bins=20, rwidth=0.8, color = '#29788E')
plt.xlabel = 'Precio x M2'
plt.ylabel = 'Count'
plt.show()

print(data_caba_clean.surface_covered_in_m2.max()) 
print(data_caba_clean.surface_covered_in_m2.min())

# Parece una distribución normal? sino fuera por los valores elevados que tenemos a partir de los 3500...
# Out:
# 405.0
# 12.0

# %%
feature_cols = ['price_aprox_usd']
target = ['price_usd_per_m2']

train_test_error(feature_cols, target)
# Out:
# RMSE: 830.1097755997107
# R2: 0.26617597245130753
# (6020,)
# (6020,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2',
                'pool', 'laundry', 'parking', 'gym', 'place_name_Puerto Madero']
target = ['price_usd_per_m2']

train_test_error(feature_cols, target)
# Out:
# RMSE: 549.6294461007273
# R2: 0.6782927452161285
# (6020,)
# (6020,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2',
                'pool', 'laundry', 'parking', 'gym', 'place_name_Puerto Madero']
target = ['price_usd_per_m2']

train_test_error_lazzo(feature_cols, target)
# Out:
# {'alpha': 0.0202281981981982, 'scores': array([0.69510763, 0.66588408, 0.66686216]), 'mean_score': 0.6759512909574559, 'zero_coefs': 1}
# r^2: 0.6779965666771557
# Imprime Alpha 0.0202281981981982
# (18059,)
# (18059,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2',
                'pool', 'laundry', 'parking', 'gym', 'place_name_Puerto Madero']
target = ['price_usd_per_m2']

train_test_error_ridge(feature_cols, target)
# Out:
# {'alpha': 0.0007106306306306308, 'scores': array([0.69541649, 0.66550128, 0.66657921]), 'mean_score': 0.6758323285747373, 'zero_coefs': 0}
# r^2: 0.6779981041655819
# Coeficientes de la regresión [ 4.64040747e-03 -1.18936234e+01  1.40194560e-01  1.73656958e+02
#  -4.92748935e+01  1.23999950e+02  2.35927393e+02  8.34837166e+02]
# (18059,)
# (18059,)

# %%
X = data_caba_clean[['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2',
        'pool', 'laundry', 'parking', 'gym', 'place_name_Puerto Madero']]

plt.figure(figsize=(13,10))
sns.heatmap(X.corr(),annot=True)
plt.title("Correlation Heatmap")
plt.show()

# Para tomar revisar!

# %%
feature_cols = ['price_aprox_usd', 'place_name_Villa del Parque',
                'pool', 'laundry', 'parking', 'gym', 
                'place_name_Agronomía', 'place_name_Villa del Parque',
                'place_name_Almagro', 'place_name_Balvanera', 'place_name_Barracas',
                'place_name_Barrio Norte', 'place_name_Belgrano', 'place_name_Boca',
                'place_name_Boedo', 'place_name_Caballito', 'place_name_Catalinas',
                'place_name_Centro / Microcentro', 'place_name_Chacarita',
                'place_name_Coghlan', 'place_name_Colegiales', 'place_name_Congreso',
                'place_name_Constitución', 'place_name_Flores', 'place_name_Floresta',
                'place_name_Las Cañitas', 'place_name_Liniers', 'place_name_Mataderos',
                'place_name_Monserrat', 'place_name_Monte Castro', 'place_name_Nuñez',
                'place_name_Once', 'place_name_Palermo', 'place_name_Palermo Chico',
                'place_name_Palermo Hollywood', 'place_name_Palermo Soho',
                'place_name_Palermo Viejo', 'place_name_Parque Avellaneda',
                'place_name_Parque Centenario', 'place_name_Parque Chacabuco',
                'place_name_Parque Chas', 'place_name_Parque Patricios',
                'place_name_Paternal', 'place_name_Pompeya', 'place_name_Puerto Madero',
                'place_name_Recoleta', 'place_name_Retiro', 'place_name_Saavedra',
                'place_name_San Cristobal', 'place_name_San Nicolás',
                'place_name_San Telmo', 'place_name_Tribunales',
                'place_name_Velez Sarsfield', 'place_name_Versalles',
                'place_name_Villa Crespo', 'place_name_Villa Devoto',
                'place_name_Villa General Mitre', 'place_name_Villa Lugano',
                'place_name_Villa Luro', 'place_name_Villa Ortuzar',
                'place_name_Villa Pueyrredón', 'place_name_Villa Real',
                'place_name_Villa Riachuelo', 'place_name_Villa Santa Rita',
                'place_name_Villa Soldati', 'place_name_Villa Urquiza']
target = ['price_usd_per_m2']

train_test_error_ridge(feature_cols, target)
# Out:
# {'alpha': 1e-05, 'scores': array([0.54047153, 0.52321648, 0.52644062]), 'mean_score': 0.5300428764635251, 'zero_coefs': 0}
# r^2: 0.5349002106863947
# Coeficientes de la regresión [ 1.06490648e-03 -2.70608189e-01  2.38268696e+02 -1.51710939e+02
#   8.91166221e+01  4.49141801e+02 -1.07936190e+02 -2.70608189e-01
#   1.84648598e+02 -6.68054565e+01 -1.87521301e+02  7.76958522e+02
#   7.52297274e+02 -3.80119425e+02  4.67902517e+01  2.94468109e+02
#  -5.88853875e+02  2.71171266e+02  1.00919290e+02  4.02586266e+02
#   3.89156083e+02 -1.48568652e+02 -1.55735855e+02 -2.77039458e+01
#  -2.02484192e+02  1.10204228e+03 -2.39799969e+02 -2.95722243e+02
#   1.10973824e+00 -7.75080769e+01  6.76855874e+02 -7.85826208e+01
#   8.97429811e+02  1.49129861e+03  8.72595362e+02  9.27860254e+02
#   9.57146217e+02 -4.73950834e+02  2.41485649e+02 -1.78127037e+02
#   1.58586173e+02 -2.08014927e+02 -1.76388099e+01 -5.44192888e+02
#   2.41464987e+03  9.54240312e+02  6.63015448e+02  1.51661345e+02
#   1.54207654e+02  9.36920111e+01  1.36072094e+02  6.51247404e+01
#  -4.97884736e+02 -9.66725702e+01  4.30464265e+02  4.07993268e+01
#  -1.44284519e+02 -6.70619203e+02 -9.84892117e+00  2.03624026e+02
#  -9.94944668e+00 -4.58984280e+02 -1.01144482e+03 -6.48000487e+01
#  -8.71735196e+02  3.05128184e+02]
# (18059,)
# (18059,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2']
target = ['price_usd_per_m2']

train_test_error_ridge(feature_cols, target)
# Out:
# {'alpha': 0.00041036036036036044, 'scores': array([0.65801584, 0.63014774, 0.62404869]), 'mean_score': 0.6374040915597678, 'zero_coefs': 0}
# r^2: 0.6410787764096421
# Coeficientes de la regresión [ 5.21225362e-03 -1.30001240e+01]
# (18059,)
# (18059,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2',
                'pool', 'laundry', 'parking', 'gym', 
                'place_name_Agronomía', 'place_name_Villa del Parque',
                'place_name_Almagro', 'place_name_Balvanera', 'place_name_Barracas',
                'place_name_Barrio Norte', 'place_name_Belgrano', 'place_name_Boca',
                'place_name_Boedo', 'place_name_Caballito', 'place_name_Catalinas',
                'place_name_Centro / Microcentro', 'place_name_Chacarita',
                'place_name_Coghlan', 'place_name_Colegiales', 'place_name_Congreso',
                'place_name_Constitución', 'place_name_Flores', 'place_name_Floresta',
                'place_name_Las Cañitas', 'place_name_Liniers', 'place_name_Mataderos',
                'place_name_Monserrat', 'place_name_Monte Castro', 'place_name_Nuñez',
                'place_name_Once', 'place_name_Palermo', 'place_name_Palermo Chico',
                'place_name_Palermo Hollywood', 'place_name_Palermo Soho',
                'place_name_Palermo Viejo', 'place_name_Parque Avellaneda',
                'place_name_Parque Centenario', 'place_name_Parque Chacabuco',
                'place_name_Parque Chas', 'place_name_Parque Patricios',
                'place_name_Paternal', 'place_name_Pompeya', 'place_name_Puerto Madero',
                'place_name_Recoleta', 'place_name_Retiro', 'place_name_Saavedra',
                'place_name_San Cristobal', 'place_name_San Nicolás',
                'place_name_San Telmo', 'place_name_Tribunales',
                'place_name_Velez Sarsfield', 'place_name_Versalles',
                'place_name_Villa Crespo', 'place_name_Villa Devoto',
                'place_name_Villa General Mitre', 'place_name_Villa Lugano',
                'place_name_Villa Luro', 'place_name_Villa Ortuzar',
                'place_name_Villa Pueyrredón', 'place_name_Villa Real',
                'place_name_Villa Riachuelo', 'place_name_Villa Santa Rita',
                'place_name_Villa Soldati', 'place_name_Villa Urquiza']
target = ['price_usd_per_m2']

train_test_error_elastic(feature_cols, target)
# Out:
# {'alpha': 1e-05, 'scores': array([0.73373538, 0.71993091, 0.72497716]), 'mean_score': 0.7262144846948996, 'zero_coefs': 0}
# r^2: 0.7204817914341851
# Coeficientes de la regresión [ 2.83763847e-03 -5.80248530e+00 -2.16076126e+00  1.67959813e+02
#  -5.60991789e+01  1.39326012e+02  2.90998060e+02 -2.69055920e+02
#  -2.48991292e+02 -1.72199583e+02 -3.46875671e+02 -3.72033976e+02
#   3.26313245e+02  3.08346183e+02 -6.01002283e+02 -2.95735871e+02
#  -8.92897258e+01  1.35498222e+02 -5.97734650e+01 -2.91952533e+02
#  -6.39541984e+00  2.69598911e+01 -4.21446019e+02 -5.09708881e+02
#  -3.14325622e+02 -4.22403341e+02  5.77473616e+02 -4.00172399e+02
#  -3.79854090e+02 -3.28769808e+02 -3.59441953e+02  2.04518591e+02
#  -3.70065863e+02  3.96805860e+02  7.50759890e+02  3.54231799e+02
#   4.11975548e+02  4.15792765e+02 -5.61237963e+02 -1.05863467e+02
#  -3.45008913e+02 -2.63946139e+02 -4.59536989e+02 -3.24601751e+02
#  -5.82876103e+02  1.43017634e+03  4.71853856e+02  2.48856020e+02
#  -1.64486314e+02 -1.61823708e+02 -2.01017705e+02 -2.20979478e+02
#  -1.86512591e+02 -3.62096464e+02 -2.25564867e+02  1.44567199e+01
#  -1.58142631e+02 -3.32671789e+02 -7.05104949e+02 -3.24494972e+02
#  -1.26820172e+02 -2.41303619e+02 -4.83537412e+02 -5.54836585e+02
#  -3.29526445e+02 -9.06461851e+02 -8.61701298e+01]
# (18059,)
# (18059,)

# %%
#Creo una nueva feature a partir de una existente para complejizar el modelo y tratar de obtener un R^2 más elevado
data_caba_clean['surface_covered_in_m2_2']=data_caba_clean['surface_covered_in_m2']**2
data_caba_clean['surface_covered_in_m2_3']=data_caba_clean['surface_covered_in_m2']**3
data_caba_clean.head()
# Out:
#    property_type    place_name  price_aprox_usd  surface_total_in_m2  \
# 0             PH     Mataderos          62000.0                 55.0
# 2      apartment     Mataderos          72000.0                 55.0
# 7      apartment      Belgrano         138000.0                 45.0
# 8      apartment      Belgrano         195000.0                 65.0
# 13     apartment  Palermo Soho         111700.0                 50.0
#
#     surface_covered_in_m2  price_usd_per_m2 rooms  \
# 0                    40.0       1127.272727     2
# 2                    55.0       1309.090909     2
# 7                    40.0       3066.666667     2
# 8                    60.0       3000.000000     3
# 13                   30.0       2234.000000     1
#
#                                           description m2_categories m2_labels  \
# 0   2 ambientes tipo casa planta baja por pasillo,...      (30, 45]       s45
# 2   2 ambientes 3er piso lateral living comedor am...      (45, 75]       s75
# 7   excelente monoambiente a estrenar amplio super...      (30, 45]       s45
# 8   excelente dos ambientes  estrenar amplio super...      (45, 75]       s75
# 13   torre i mondrian. 3 ambientes con terraza y d...       (0, 30]       s45
#
#     number_rooms rooms_upon_categories  pool  laundry  parking  gym  \
# 0            2.0                     2   0.0      1.0      0.0  0.0
# 2            2.0                     3   0.0      1.0      0.0  0.0
# 7            NaN                     2   1.0      1.0      0.0  0.0
# 8            NaN                     3   1.0      1.0      0.0  0.0
# 13           3.0                     2   1.0      0.0      0.0  1.0
#
#     prop_type_apartment  prop_type_house  prop_type_store  m2_label_s45  \
# 0                     0                0                0             1
# 2                     1                0                0             0
# 7                     1                0                0             1
# 8                     1                0                0             0
# 13                    1                0                0             1
#
#     m2_label_s75  m2_label_s150  m2_label_m220  place_name_Agronomía  \
# 0              0              0              0                     0
# 2              1              0              0                     0
# 7              0              0              0                     0
# 8              1              0              0                     0
# 13             0              0              0                     0
#
#     place_name_Almagro  place_name_Balvanera  place_name_Barracas  \
# 0                    0                     0                    0
# 2                    0                     0                    0
# 7                    0                     0                    0
# 8                    0                     0                    0
# 13                   0                     0                    0
#
#     place_name_Barrio Norte  place_name_Belgrano  place_name_Boca  \
# 0                         0                    0                0
# 2                         0                    0                0
# 7                         0                    1                0
# 8                         0                    1                0
# 13                        0                    0                0
#
#     place_name_Boedo  place_name_Caballito  place_name_Catalinas  \
# 0                  0                     0                     0
# 2                  0                     0                     0
# 7                  0                     0                     0
# 8                  0                     0                     0
# 13                 0                     0                     0
#
#     place_name_Centro / Microcentro  place_name_Chacarita  place_name_Coghlan  \
# 0                                 0                     0                   0
# 2                                 0                     0                   0
# 7                                 0                     0                   0
# 8                                 0                     0                   0
# 13                                0                     0                   0
#
#     place_name_Colegiales  place_name_Congreso  place_name_Constitución  \
# 0                       0                    0                        0
# 2                       0                    0                        0
# 7                       0                    0                        0
# 8                       0                    0                        0
# 13                      0                    0                        0
#
#     place_name_Flores  place_name_Floresta  place_name_Las Cañitas  \
# 0                   0                    0                       0
# 2                   0                    0                       0
# 7                   0                    0                       0
# 8                   0                    0                       0
# 13                  0                    0                       0
#
#     place_name_Liniers  place_name_Mataderos  place_name_Monserrat  \
# 0                    0                     1                     0
# 2                    0                     1                     0
# 7                    0                     0                     0
# 8                    0                     0                     0
# 13                   0                     0                     0
#
#     place_name_Monte Castro  place_name_Nuñez  place_name_Once  \
# 0                         0                 0                0
# 2                         0                 0                0
# 7                         0                 0                0
# 8                         0                 0                0
# 13                        0                 0                0
#
#     place_name_Palermo  place_name_Palermo Chico  \
# 0                    0                         0
# 2                    0                         0
# 7                    0                         0
# 8                    0                         0
# 13                   0                         0
#
#     place_name_Palermo Hollywood  place_name_Palermo Soho  \
# 0                              0                        0
# 2                              0                        0
# 7                              0                        0
# 8                              0                        0
# 13                             0                        1
#
#     place_name_Palermo Viejo  place_name_Parque Avellaneda  \
# 0                          0                             0
# 2                          0                             0
# 7                          0                             0
# 8                          0                             0
# 13                         0                             0
#
#     place_name_Parque Centenario  place_name_Parque Chacabuco  \
# 0                              0                            0
# 2                              0                            0
# 7                              0                            0
# 8                              0                            0
# 13                             0                            0
#
#     place_name_Parque Chas  place_name_Parque Patricios  place_name_Paternal  \
# 0                        0                            0                    0
# 2                        0                            0                    0
# 7                        0                            0                    0
# 8                        0                            0                    0
# 13                       0                            0                    0
#
#     place_name_Pompeya  place_name_Puerto Madero  place_name_Recoleta  \
# 0                    0                         0                    0
# 2                    0                         0                    0
# 7                    0                         0                    0
# 8                    0                         0                    0
# 13                   0                         0                    0
#
#     place_name_Retiro  place_name_Saavedra  place_name_San Cristobal  \
# 0                   0                    0                         0
# 2                   0                    0                         0
# 7                   0                    0                         0
# 8                   0                    0                         0
# 13                  0                    0                         0
#
#     place_name_San Nicolás  place_name_San Telmo  place_name_Tribunales  \
# 0                        0                     0                      0
# 2                        0                     0                      0
# 7                        0                     0                      0
# 8                        0                     0                      0
# 13                       0                     0                      0
#
#     place_name_Velez Sarsfield  place_name_Versalles  place_name_Villa Crespo  \
# 0                            0                     0                        0
# 2                            0                     0                        0
# 7                            0                     0                        0
# 8                            0                     0                        0
# 13                           0                     0                        0
#
#     place_name_Villa Devoto  place_name_Villa General Mitre  \
# 0                         0                               0
# 2                         0                               0
# 7                         0                               0
# 8                         0                               0
# 13                        0                               0
#
#     place_name_Villa Lugano  place_name_Villa Luro  place_name_Villa Ortuzar  \
# 0                         0                      0                         0
# 2                         0                      0                         0
# 7                         0                      0                         0
# 8                         0                      0                         0
# 13                        0                      0                         0
#
#     place_name_Villa Pueyrredón  place_name_Villa Real  \
# 0                             0                      0
# 2                             0                      0
# 7                             0                      0
# 8                             0                      0
# 13                            0                      0
#
#     place_name_Villa Riachuelo  place_name_Villa Santa Rita  \
# 0                            0                            0
# 2                            0                            0
# 7                            0                            0
# 8                            0                            0
# 13                           0                            0
#
#     place_name_Villa Soldati  place_name_Villa Urquiza  \
# 0                          0                         0
# 2                          0                         0
# 7                          0                         0
# 8                          0                         0
# 13                         0                         0
#
#     place_name_Villa del Parque  surface_covered_in_m2_2  \
# 0                             0                   1600.0
# 2                             0                   3025.0
# 7                             0                   1600.0
# 8                             0                   3600.0
# 13                            0                    900.0
#
#     surface_covered_in_m2_3
# 0                   64000.0
# 2                  166375.0
# 7                   64000.0
# 8                  216000.0
# 13                  27000.0

# %%
# tomo las nueva feature 'surface_covered_in_m2_2'
X = data_caba_clean[['price_aprox_usd', 'surface_total_in_m2','pool', 'laundry', 'parking', 'gym',
                     'surface_covered_in_m2_2','surface_covered_in_m2']]

plt.figure(figsize=(13,10))
sns.heatmap(X.corr(),annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2','pool', 'laundry', 'parking', 'gym',
                'surface_covered_in_m2','surface_covered_in_m2_2']
target = ['price_usd_per_m2']

train_test_error(feature_cols, target)
# Out:
# RMSE: 557.3177060462511
# R2: 0.6692296651394525
# (6020,)
# (6020,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2','pool', 'laundry', 'parking', 'gym',
                'surface_covered_in_m2','surface_covered_in_m2_2']
target = ['price_usd_per_m2']

train_test_error_lazzo(feature_cols, target)
# Out:
# {'alpha': 0.02863576576576577, 'scores': array([0.68362894, 0.6557    , 0.65631136]), 'mean_score': 0.6652134357567493, 'zero_coefs': 2}
# r^2: 0.6678445947986789
# Imprime Alpha 0.02863576576576577
# (18059,)
# (18059,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2','pool', 'laundry', 'parking', 'gym',
                'surface_covered_in_m2','surface_covered_in_m2_2']
target = ['price_usd_per_m2']

train_test_error_ridge(feature_cols, target)
# Out:
# {'alpha': 0.0008107207207207209, 'scores': array([0.68323783, 0.65513225, 0.65585434]), 'mean_score': 0.6647414730519815, 'zero_coefs': 0}
# r^2: 0.6678485384758763
# Coeficientes de la regresión [ 4.87586549e-03 -1.23049452e+01  1.80987659e+02 -5.45072299e+01
#   1.28027881e+02  2.67203821e+02 -8.12658145e-02  6.16720967e-04]
# (18059,)
# (18059,)

# %%
#Pruebo con todas las features y con la creada surface_covered_in_m2_2
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2', 'surface_covered_in_m2_2',
                'pool', 'laundry', 'parking', 'gym', 
                'place_name_Agronomía', 'place_name_Villa del Parque',
                'place_name_Almagro', 'place_name_Balvanera', 'place_name_Barracas',
                'place_name_Barrio Norte', 'place_name_Belgrano', 'place_name_Boca',
                'place_name_Boedo', 'place_name_Caballito', 'place_name_Catalinas',
                'place_name_Centro / Microcentro', 'place_name_Chacarita',
                'place_name_Coghlan', 'place_name_Colegiales', 'place_name_Congreso',
                'place_name_Constitución', 'place_name_Flores', 'place_name_Floresta',
                'place_name_Las Cañitas', 'place_name_Liniers', 'place_name_Mataderos',
                'place_name_Monserrat', 'place_name_Monte Castro', 'place_name_Nuñez',
                'place_name_Once', 'place_name_Palermo', 'place_name_Palermo Chico',
                'place_name_Palermo Hollywood', 'place_name_Palermo Soho',
                'place_name_Palermo Viejo', 'place_name_Parque Avellaneda',
                'place_name_Parque Centenario', 'place_name_Parque Chacabuco',
                'place_name_Parque Chas', 'place_name_Parque Patricios',
                'place_name_Paternal', 'place_name_Pompeya', 'place_name_Puerto Madero',
                'place_name_Recoleta', 'place_name_Retiro', 'place_name_Saavedra',
                'place_name_San Cristobal', 'place_name_San Nicolás',
                'place_name_San Telmo', 'place_name_Tribunales',
                'place_name_Velez Sarsfield', 'place_name_Versalles',
                'place_name_Villa Crespo', 'place_name_Villa Devoto',
                'place_name_Villa General Mitre', 'place_name_Villa Lugano',
                'place_name_Villa Luro', 'place_name_Villa Ortuzar',
                'place_name_Villa Pueyrredón', 'place_name_Villa Real',
                'place_name_Villa Riachuelo', 'place_name_Villa Santa Rita',
                'place_name_Villa Soldati', 'place_name_Villa Urquiza']
target = ['price_usd_per_m2']

train_test_error(feature_cols, target)
# Out:
# RMSE: 486.2277105477275
# R2: 0.7482321430000742
# (6020,)
# (6020,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2_2', 'surface_covered_in_m2',
                'pool', 'laundry', 'parking', 'gym', 
                'place_name_Agronomía', 'place_name_Villa del Parque',
                'place_name_Almagro', 'place_name_Balvanera', 'place_name_Barracas',
                'place_name_Barrio Norte', 'place_name_Belgrano', 'place_name_Boca',
                'place_name_Boedo', 'place_name_Caballito', 'place_name_Catalinas',
                'place_name_Centro / Microcentro', 'place_name_Chacarita',
                'place_name_Coghlan', 'place_name_Colegiales', 'place_name_Congreso',
                'place_name_Constitución', 'place_name_Flores', 'place_name_Floresta',
                'place_name_Las Cañitas', 'place_name_Liniers', 'place_name_Mataderos',
                'place_name_Monserrat', 'place_name_Monte Castro', 'place_name_Nuñez',
                'place_name_Once', 'place_name_Palermo', 'place_name_Palermo Chico',
                'place_name_Palermo Hollywood', 'place_name_Palermo Soho',
                'place_name_Palermo Viejo', 'place_name_Parque Avellaneda',
                'place_name_Parque Centenario', 'place_name_Parque Chacabuco',
                'place_name_Parque Chas', 'place_name_Parque Patricios',
                'place_name_Paternal', 'place_name_Pompeya', 'place_name_Puerto Madero',
                'place_name_Recoleta', 'place_name_Retiro', 'place_name_Saavedra',
                'place_name_San Cristobal', 'place_name_San Nicolás',
                'place_name_San Telmo', 'place_name_Tribunales',
                'place_name_Velez Sarsfield', 'place_name_Versalles',
                'place_name_Villa Crespo', 'place_name_Villa Devoto',
                'place_name_Villa General Mitre', 'place_name_Villa Lugano',
                'place_name_Villa Luro', 'place_name_Villa Ortuzar',
                'place_name_Villa Pueyrredón', 'place_name_Villa Real',
                'place_name_Villa Riachuelo', 'place_name_Villa Santa Rita',
                'place_name_Villa Soldati', 'place_name_Villa Urquiza']
target = ['price_usd_per_m2']

train_test_error_lazzo(feature_cols, target)
# Out:
# {'alpha': 0.0030127027027027032, 'scores': array([0.75377272, 0.73483756, 0.73344638]), 'mean_score': 0.7406855501184214, 'zero_coefs': 3}
# r^2: 0.7458675760771666
# Imprime Alpha 0.0030127027027027032
# (18059,)
# (18059,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2_2', 'surface_covered_in_m2',
                'pool', 'laundry', 'parking', 'gym', 
                'place_name_Agronomía', 'place_name_Villa del Parque',
                'place_name_Almagro', 'place_name_Balvanera', 'place_name_Barracas',
                'place_name_Barrio Norte', 'place_name_Belgrano', 'place_name_Boca',
                'place_name_Boedo', 'place_name_Caballito', 'place_name_Catalinas',
                'place_name_Centro / Microcentro', 'place_name_Chacarita',
                'place_name_Coghlan', 'place_name_Colegiales', 'place_name_Congreso',
                'place_name_Constitución', 'place_name_Flores', 'place_name_Floresta',
                'place_name_Las Cañitas', 'place_name_Liniers', 'place_name_Mataderos',
                'place_name_Monserrat', 'place_name_Monte Castro', 'place_name_Nuñez',
                'place_name_Once', 'place_name_Palermo', 'place_name_Palermo Chico',
                'place_name_Palermo Hollywood', 'place_name_Palermo Soho',
                'place_name_Palermo Viejo', 'place_name_Parque Avellaneda',
                'place_name_Parque Centenario', 'place_name_Parque Chacabuco',
                'place_name_Parque Chas', 'place_name_Parque Patricios',
                'place_name_Paternal', 'place_name_Pompeya', 'place_name_Puerto Madero',
                'place_name_Recoleta', 'place_name_Retiro', 'place_name_Saavedra',
                'place_name_San Cristobal', 'place_name_San Nicolás',
                'place_name_San Telmo', 'place_name_Tribunales',
                'place_name_Velez Sarsfield', 'place_name_Versalles',
                'place_name_Villa Crespo', 'place_name_Villa Devoto',
                'place_name_Villa General Mitre', 'place_name_Villa Lugano',
                'place_name_Villa Luro', 'place_name_Villa Ortuzar',
                'place_name_Villa Pueyrredón', 'place_name_Villa Real',
                'place_name_Villa Riachuelo', 'place_name_Villa Santa Rita',
                'place_name_Villa Soldati', 'place_name_Villa Urquiza']
target = ['price_usd_per_m2']

train_test_error_ridge(feature_cols, target)
# Out:
# {'alpha': 0.0006105405405405406, 'scores': array([0.75327142, 0.73478364, 0.73346477]), 'mean_score': 0.7405066098156391, 'zero_coefs': 0}
# r^2: 0.7458835985906784
# Coeficientes de la regresión [ 3.86674760e-03 -1.06716255e+01  3.77185534e-03 -8.26736336e-01
#   1.51950503e+02 -5.03902403e+01  1.27220367e+02  2.38882456e+02
#   3.69254752e+01  1.14789269e+01  6.59645402e+01 -1.07951900e+02
#  -9.89940035e+01  5.21523545e+02  5.20269798e+02 -3.54979073e+02
#  -5.11708904e+01  1.45468811e+02  5.05894319e+02  1.65625367e+02
#  -7.27557457e+01  2.38376414e+02  2.77879834e+02 -1.85748899e+02
#  -2.94257242e+02 -6.68040956e+01 -1.41892717e+02  7.84987537e+02
#  -1.00764784e+02 -5.86511357e+01 -1.06389929e+02 -9.20329448e+01
#   4.11716121e+02 -1.32639599e+02  5.91646442e+02  7.48999632e+02
#   5.68890567e+02  6.42679459e+02  6.15605776e+02 -2.74958708e+02
#   1.30894335e+02 -3.74125910e+01 -4.10040756e+01 -2.07842501e+02
#  -7.51249963e+01 -2.43151625e+02  1.41472545e+03  6.43492027e+02
#   4.10404647e+02  9.87152101e+01  9.75447305e+01  3.57556388e+01
#   9.09395681e+00  5.02139820e+01  8.73838205e+01  1.24682305e+02
#   2.45531180e+02  1.43068949e+02 -4.27309717e+01 -4.00577409e+02
#  -7.84933950e+01  1.24968560e+02  5.14002652e+01 -1.00208658e+02
#   7.27511955e+01 -4.91686821e+01 -6.23167871e+02  1.50670705e+02]
# (18059,)
# (18059,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2_2', 'surface_covered_in_m2',
                'pool', 'laundry', 'parking', 'gym', 
                'place_name_Agronomía', 'place_name_Villa del Parque',
                'place_name_Almagro', 'place_name_Balvanera', 'place_name_Barracas',
                'place_name_Barrio Norte', 'place_name_Belgrano', 'place_name_Boca',
                'place_name_Boedo', 'place_name_Caballito', 'place_name_Catalinas',
                'place_name_Centro / Microcentro', 'place_name_Chacarita',
                'place_name_Coghlan', 'place_name_Colegiales', 'place_name_Congreso',
                'place_name_Constitución', 'place_name_Flores', 'place_name_Floresta',
                'place_name_Las Cañitas', 'place_name_Liniers', 'place_name_Mataderos',
                'place_name_Monserrat', 'place_name_Monte Castro', 'place_name_Nuñez',
                'place_name_Once', 'place_name_Palermo', 'place_name_Palermo Chico',
                'place_name_Palermo Hollywood', 'place_name_Palermo Soho',
                'place_name_Palermo Viejo', 'place_name_Parque Avellaneda',
                'place_name_Parque Centenario', 'place_name_Parque Chacabuco',
                'place_name_Parque Chas', 'place_name_Parque Patricios',
                'place_name_Paternal', 'place_name_Pompeya', 'place_name_Puerto Madero',
                'place_name_Recoleta', 'place_name_Retiro', 'place_name_Saavedra',
                'place_name_San Cristobal', 'place_name_San Nicolás',
                'place_name_San Telmo', 'place_name_Tribunales',
                'place_name_Velez Sarsfield', 'place_name_Versalles',
                'place_name_Villa Crespo', 'place_name_Villa Devoto',
                'place_name_Villa General Mitre', 'place_name_Villa Lugano',
                'place_name_Villa Luro', 'place_name_Villa Ortuzar',
                'place_name_Villa Pueyrredón', 'place_name_Villa Real',
                'place_name_Villa Riachuelo', 'place_name_Villa Santa Rita',
                'place_name_Villa Soldati', 'place_name_Villa Urquiza']
target = ['price_usd_per_m2']

train_test_error_elastic(feature_cols, target)
# Out:
# {'alpha': 1e-05, 'scores': array([0.73391312, 0.71955246, 0.72520007]), 'mean_score': 0.7262218836742727, 'zero_coefs': 0}
# r^2: 0.7202580854904201
# Coeficientes de la regresión [ 2.84124507e-03 -5.76711368e+00 -5.74160389e-04 -2.05013908e+00
#   1.68294838e+02 -5.67115597e+01  1.39204840e+02  2.90571871e+02
#  -2.68090494e+02 -2.48879885e+02 -1.71997855e+02 -3.47008027e+02
#  -3.72555870e+02  3.26122721e+02  3.08197128e+02 -6.00979384e+02
#  -2.94304853e+02 -8.92641192e+01  1.43918777e+02 -5.89844241e+01
#  -2.91484565e+02 -5.91266436e+00  2.70356738e+01 -4.21099128e+02
#  -5.08371959e+02 -3.14358222e+02 -4.22881052e+02  5.76861069e+02
#  -4.00257280e+02 -3.79261444e+02 -3.27721849e+02 -3.59938331e+02
#   2.04078996e+02 -3.70032885e+02  3.96366219e+02  7.50386021e+02
#   3.54486494e+02  4.12755807e+02  4.14206625e+02 -5.61756287e+02
#  -1.06546567e+02 -3.45698826e+02 -2.63283752e+02 -4.59755980e+02
#  -3.24517869e+02 -5.84115884e+02  1.42765474e+03  4.71337506e+02
#   2.48619119e+02 -1.64572995e+02 -1.61084700e+02 -2.01022683e+02
#  -2.19774245e+02 -1.86681382e+02 -3.61685479e+02 -2.26859499e+02
#   1.48778533e+01 -1.58434070e+02 -3.32461984e+02 -7.05816359e+02
#  -3.24379977e+02 -1.25978918e+02 -2.41724887e+02 -4.85558100e+02
#  -5.59245355e+02 -3.29629299e+02 -9.07722874e+02 -8.60496404e+01]
# (18059,)
# (18059,)

# %%
# agrego una nueva feature ('surface_covered_in_m2_3')

# %%
# tomo las nueva features
X = data_caba_clean[['price_aprox_usd', 'surface_total_in_m2','pool', 'laundry', 'parking', 'gym',
                     'surface_covered_in_m2_2','surface_covered_in_m2','surface_covered_in_m2_3']]

plt.figure(figsize=(13,10))
sns.heatmap(X.corr(),annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2','pool', 'laundry', 'parking', 'gym',
                'surface_covered_in_m2','surface_covered_in_m2_2','surface_covered_in_m2_3']
target = ['price_usd_per_m2']

train_test_error(feature_cols, target)
# Out:
# RMSE: 556.6350596985234
# R2: 0.67003947566705
# (6020,)
# (6020,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2','pool', 'laundry', 'parking', 'gym',
                'surface_covered_in_m2','surface_covered_in_m2_2','surface_covered_in_m2_3']
target = ['price_usd_per_m2']

train_test_error_lazzo(feature_cols, target)
# Out:
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42477289.06878376, tolerance: 1398954.1223814345
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34239356.78705883, tolerance: 1405897.9930900729
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32616016.893105507, tolerance: 1411963.1621199977
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32295203.94620943, tolerance: 1383270.623426265
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32997600.360091686, tolerance: 1408004.6803013424
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 187239787.94191647, tolerance: 1752054.0101051563
#   positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31646811.788624287, tolerance: 947924.1036976418
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28209070.29973364, tolerance: 937776.1180144375
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30998961.622966766, tolerance: 924991.9854141667
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27881773.40916872, tolerance: 937420.4931314469
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32097338.848561287, tolerance: 943571.2564335983
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26645325.29740095, tolerance: 932013.9143395191
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21479496.712952614, tolerance: 926454.8079427193
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20366558.715639114, tolerance: 927011.8367996395
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18607454.333251, tolerance: 924795.4596722585
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20436591.732154846, tolerance: 930941.2950547438
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12405283.66478157, tolerance: 1160334.8270351326
#   positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24009290.417141914, tolerance: 942445.9751192044
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19698257.59142399, tolerance: 936924.7396379123
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18392220.277614594, tolerance: 933577.6306486218
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18288715.963109016, tolerance: 944720.9395462277
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17699090.748954773, tolerance: 925142.7654685023
#   tol, rng, random, positive)
# {'alpha': 0.0002101801801801802, 'scores': array([0.68362684, 0.65522623, 0.65631238]), 'mean_score': 0.6650551513689906, 'zero_coefs': 0}
# r^2: 0.6684861701766659
# Imprime Alpha 0.0002101801801801802
# (18059,)
# (18059,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2','pool', 'laundry', 'parking', 'gym',
                'surface_covered_in_m2','surface_covered_in_m2_2','surface_covered_in_m2_3']
target = ['price_usd_per_m2']

train_test_error_ridge(feature_cols, target)
# Out:
# {'alpha': 0.0003102702702702703, 'scores': array([0.68401283, 0.65519958, 0.65630325]), 'mean_score': 0.6651718879013215, 'zero_coefs': 0}
# r^2: 0.6684875442649552
# Coeficientes de la regresión [ 4.88195152e-03 -1.23712400e+01  1.81425391e+02 -5.27088928e+01
#   1.26831797e+02  2.66873513e+02 -2.46226564e+00  1.92499607e-02
#  -3.62965522e-05]
# (18059,)
# (18059,)

# %%
# con todas las features
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2', 'surface_covered_in_m2_2',
                'surface_covered_in_m2_3',
                'pool', 'laundry', 'parking', 'gym', 
                'place_name_Agronomía', 'place_name_Villa del Parque',
                'place_name_Almagro', 'place_name_Balvanera', 'place_name_Barracas',
                'place_name_Barrio Norte', 'place_name_Belgrano', 'place_name_Boca',
                'place_name_Boedo', 'place_name_Caballito', 'place_name_Catalinas',
                'place_name_Centro / Microcentro', 'place_name_Chacarita',
                'place_name_Coghlan', 'place_name_Colegiales', 'place_name_Congreso',
                'place_name_Constitución', 'place_name_Flores', 'place_name_Floresta',
                'place_name_Las Cañitas', 'place_name_Liniers', 'place_name_Mataderos',
                'place_name_Monserrat', 'place_name_Monte Castro', 'place_name_Nuñez',
                'place_name_Once', 'place_name_Palermo', 'place_name_Palermo Chico',
                'place_name_Palermo Hollywood', 'place_name_Palermo Soho',
                'place_name_Palermo Viejo', 'place_name_Parque Avellaneda',
                'place_name_Parque Centenario', 'place_name_Parque Chacabuco',
                'place_name_Parque Chas', 'place_name_Parque Patricios',
                'place_name_Paternal', 'place_name_Pompeya', 'place_name_Puerto Madero',
                'place_name_Recoleta', 'place_name_Retiro', 'place_name_Saavedra',
                'place_name_San Cristobal', 'place_name_San Nicolás',
                'place_name_San Telmo', 'place_name_Tribunales',
                'place_name_Velez Sarsfield', 'place_name_Versalles',
                'place_name_Villa Crespo', 'place_name_Villa Devoto',
                'place_name_Villa General Mitre', 'place_name_Villa Lugano',
                'place_name_Villa Luro', 'place_name_Villa Ortuzar',
                'place_name_Villa Pueyrredón', 'place_name_Villa Real',
                'place_name_Villa Riachuelo', 'place_name_Villa Santa Rita',
                'place_name_Villa Soldati', 'place_name_Villa Urquiza']
target = ['price_usd_per_m2']

train_test_error(feature_cols, target)
# Out:
# RMSE: 484.9272904984266
# R2: 0.7495770525541883
# (6020,)
# (6020,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2', 'surface_covered_in_m2_2',
                'surface_covered_in_m2_3',
                'pool', 'laundry', 'parking', 'gym', 
                'place_name_Agronomía', 'place_name_Villa del Parque',
                'place_name_Almagro', 'place_name_Balvanera', 'place_name_Barracas',
                'place_name_Barrio Norte', 'place_name_Belgrano', 'place_name_Boca',
                'place_name_Boedo', 'place_name_Caballito', 'place_name_Catalinas',
                'place_name_Centro / Microcentro', 'place_name_Chacarita',
                'place_name_Coghlan', 'place_name_Colegiales', 'place_name_Congreso',
                'place_name_Constitución', 'place_name_Flores', 'place_name_Floresta',
                'place_name_Las Cañitas', 'place_name_Liniers', 'place_name_Mataderos',
                'place_name_Monserrat', 'place_name_Monte Castro', 'place_name_Nuñez',
                'place_name_Once', 'place_name_Palermo', 'place_name_Palermo Chico',
                'place_name_Palermo Hollywood', 'place_name_Palermo Soho',
                'place_name_Palermo Viejo', 'place_name_Parque Avellaneda',
                'place_name_Parque Centenario', 'place_name_Parque Chacabuco',
                'place_name_Parque Chas', 'place_name_Parque Patricios',
                'place_name_Paternal', 'place_name_Pompeya', 'place_name_Puerto Madero',
                'place_name_Recoleta', 'place_name_Retiro', 'place_name_Saavedra',
                'place_name_San Cristobal', 'place_name_San Nicolás',
                'place_name_San Telmo', 'place_name_Tribunales',
                'place_name_Velez Sarsfield', 'place_name_Versalles',
                'place_name_Villa Crespo', 'place_name_Villa Devoto',
                'place_name_Villa General Mitre', 'place_name_Villa Lugano',
                'place_name_Villa Luro', 'place_name_Villa Ortuzar',
                'place_name_Villa Pueyrredón', 'place_name_Villa Real',
                'place_name_Villa Riachuelo', 'place_name_Villa Santa Rita',
                'place_name_Villa Soldati', 'place_name_Villa Urquiza']
target = ['price_usd_per_m2']

train_test_error_lazzo(feature_cols, target)
# Out:
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38998770.31522703, tolerance: 1398954.1223814345
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32071101.06579542, tolerance: 1405897.9930900729
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29456629.998895645, tolerance: 1411963.1621199977
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29827147.18848896, tolerance: 1383270.623426265
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30364242.474990845, tolerance: 1408004.6803013424
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16721702.737393856, tolerance: 1752054.0101051563
#   positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28468853.178714275, tolerance: 947924.1036976418
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27397934.51672864, tolerance: 937776.1180144375
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28399767.517133713, tolerance: 924991.9854141667
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26193512.93290043, tolerance: 937420.4931314469
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29713882.23978567, tolerance: 943571.2564335983
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41514159.15489769, tolerance: 1172966.0341017111
#   positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24500155.18512249, tolerance: 932013.9143395191
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19650920.99054694, tolerance: 926454.8079427193
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19318806.226811886, tolerance: 927011.8367996395
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18355626.55734682, tolerance: 924795.4596722585
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17821853.963777542, tolerance: 930941.2950547438
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47674847.13707018, tolerance: 1160334.8270351326
#   positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22009518.696917534, tolerance: 942445.9751192044
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18288570.967621803, tolerance: 936924.7396379123
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17721478.360895157, tolerance: 933577.6306486218
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15435714.82742548, tolerance: 944720.9395462277
#   tol, rng, random, positive)
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16764217.70579958, tolerance: 925142.7654685023
#   tol, rng, random, positive)
# {'alpha': 0.0008107207207207209, 'scores': array([0.75417637, 0.73482287, 0.73384746]), 'mean_score': 0.7409489018477026, 'zero_coefs': 0}
# r^2: 0.7466365363366966
# Imprime Alpha 0.0008107207207207209
# C:\Users\Ignacio\anaconda3\envs\dhdsblend\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1778568.1375203133, tolerance: 1170709.568590547
#   positive)
# (18059,)
# (18059,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2', 'surface_covered_in_m2_2',
                'surface_covered_in_m2_3',
                'pool', 'laundry', 'parking', 'gym', 
                'place_name_Agronomía', 'place_name_Villa del Parque',
                'place_name_Almagro', 'place_name_Balvanera', 'place_name_Barracas',
                'place_name_Barrio Norte', 'place_name_Belgrano', 'place_name_Boca',
                'place_name_Boedo', 'place_name_Caballito', 'place_name_Catalinas',
                'place_name_Centro / Microcentro', 'place_name_Chacarita',
                'place_name_Coghlan', 'place_name_Colegiales', 'place_name_Congreso',
                'place_name_Constitución', 'place_name_Flores', 'place_name_Floresta',
                'place_name_Las Cañitas', 'place_name_Liniers', 'place_name_Mataderos',
                'place_name_Monserrat', 'place_name_Monte Castro', 'place_name_Nuñez',
                'place_name_Once', 'place_name_Palermo', 'place_name_Palermo Chico',
                'place_name_Palermo Hollywood', 'place_name_Palermo Soho',
                'place_name_Palermo Viejo', 'place_name_Parque Avellaneda',
                'place_name_Parque Centenario', 'place_name_Parque Chacabuco',
                'place_name_Parque Chas', 'place_name_Parque Patricios',
                'place_name_Paternal', 'place_name_Pompeya', 'place_name_Puerto Madero',
                'place_name_Recoleta', 'place_name_Retiro', 'place_name_Saavedra',
                'place_name_San Cristobal', 'place_name_San Nicolás',
                'place_name_San Telmo', 'place_name_Tribunales',
                'place_name_Velez Sarsfield', 'place_name_Versalles',
                'place_name_Villa Crespo', 'place_name_Villa Devoto',
                'place_name_Villa General Mitre', 'place_name_Villa Lugano',
                'place_name_Villa Luro', 'place_name_Villa Ortuzar',
                'place_name_Villa Pueyrredón', 'place_name_Villa Real',
                'place_name_Villa Riachuelo', 'place_name_Villa Santa Rita',
                'place_name_Villa Soldati', 'place_name_Villa Urquiza']
target = ['price_usd_per_m2']

train_test_error_ridge(feature_cols, target)
# Out:
# {'alpha': 0.0001100900900900901, 'scores': array([0.75414738, 0.73479578, 0.73393736]), 'mean_score': 0.7409601742545279, 'zero_coefs': 0}
# r^2: 0.7466665973584556
# Coeficientes de la regresión [ 3.87360738e-03 -1.07297331e+01 -3.47048863e+00  2.41660984e-02
#  -3.94838878e-05  1.53033548e+02 -4.79400155e+01  1.25574132e+02
#   2.38150804e+02  7.38945145e+01  4.63571607e+01  9.44864001e+01
#  -7.69898781e+01 -6.98070965e+01  5.50077156e+02  5.48731840e+02
#  -3.23170758e+02 -3.67113575e+01  1.74904834e+02  4.76172917e+02
#   1.89193253e+02 -4.59835223e+01  2.64801952e+02  3.05730359e+02
#  -1.58637866e+02 -2.70087045e+02 -3.79699437e+01 -1.09147038e+02
#   8.10632227e+02 -6.97341323e+01 -3.36757190e+01 -8.31713684e+01
#  -5.96099804e+01  4.43941305e+02 -1.02080951e+02  6.20376199e+02
#   7.66737395e+02  5.96005784e+02  6.67918064e+02  6.46067988e+02
#  -2.46279968e+02  1.61617711e+02 -5.30813715e+00 -1.90783646e+01
#  -1.77479315e+02 -4.90510741e+01 -2.11357206e+02  1.44144733e+03
#   6.67706947e+02  4.31400411e+02  1.30063750e+02  1.26289570e+02
#   6.23309131e+01  3.23041013e+01  7.79640756e+01  1.17679904e+02
#   1.54818452e+02  2.72699666e+02  1.72187491e+02 -2.12889652e+01
#  -3.66234026e+02 -4.54539795e+01  1.52252782e+02  8.33004270e+01
#  -6.40532020e+01  1.03615569e+02 -2.30436993e+01 -5.82562751e+02
#   1.79511793e+02]
# (18059,)
# (18059,)

# %%
feature_cols = ['price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2', 'surface_covered_in_m2_2',
                'surface_covered_in_m2_3',
                'pool', 'laundry', 'parking', 'gym', 
                'place_name_Agronomía', 'place_name_Villa del Parque',
                'place_name_Almagro', 'place_name_Balvanera', 'place_name_Barracas',
                'place_name_Barrio Norte', 'place_name_Belgrano', 'place_name_Boca',
                'place_name_Boedo', 'place_name_Caballito', 'place_name_Catalinas',
                'place_name_Centro / Microcentro', 'place_name_Chacarita',
                'place_name_Coghlan', 'place_name_Colegiales', 'place_name_Congreso',
                'place_name_Constitución', 'place_name_Flores', 'place_name_Floresta',
                'place_name_Las Cañitas', 'place_name_Liniers', 'place_name_Mataderos',
                'place_name_Monserrat', 'place_name_Monte Castro', 'place_name_Nuñez',
                'place_name_Once', 'place_name_Palermo', 'place_name_Palermo Chico',
                'place_name_Palermo Hollywood', 'place_name_Palermo Soho',
                'place_name_Palermo Viejo', 'place_name_Parque Avellaneda',
                'place_name_Parque Centenario', 'place_name_Parque Chacabuco',
                'place_name_Parque Chas', 'place_name_Parque Patricios',
                'place_name_Paternal', 'place_name_Pompeya', 'place_name_Puerto Madero',
                'place_name_Recoleta', 'place_name_Retiro', 'place_name_Saavedra',
                'place_name_San Cristobal', 'place_name_San Nicolás',
                'place_name_San Telmo', 'place_name_Tribunales',
                'place_name_Velez Sarsfield', 'place_name_Versalles',
                'place_name_Villa Crespo', 'place_name_Villa Devoto',
                'place_name_Villa General Mitre', 'place_name_Villa Lugano',
                'place_name_Villa Luro', 'place_name_Villa Ortuzar',
                'place_name_Villa Pueyrredón', 'place_name_Villa Real',
                'place_name_Villa Riachuelo', 'place_name_Villa Santa Rita',
                'place_name_Villa Soldati', 'place_name_Villa Urquiza']
target = ['price_usd_per_m2']

train_test_error_elastic(feature_cols, target)
# Out:
# {'alpha': 1e-05, 'scores': array([0.73381875, 0.71967818, 0.72523846]), 'mean_score': 0.7262451307029689, 'zero_coefs': 0}
# r^2: 0.7203783073153598
# Coeficientes de la regresión [ 2.84105237e-03 -5.76485609e+00 -2.05923352e+00 -1.31152665e-03
#   2.64383683e-06  1.67597286e+02 -5.59730579e+01  1.39536553e+02
#   2.90804881e+02 -2.69482510e+02 -2.49272971e+02 -1.72229239e+02
#  -3.46741790e+02 -3.71761626e+02  3.26467396e+02  3.08221980e+02
#  -6.01052093e+02 -2.95159791e+02 -8.94088987e+01  1.42254591e+02
#  -5.92730458e+01 -2.92083512e+02 -6.52645956e+00  2.69177584e+01
#  -4.21123572e+02 -5.09618012e+02 -3.14215690e+02 -4.22547742e+02
#   5.77526513e+02 -4.00238140e+02 -3.79307165e+02 -3.28366578e+02
#  -3.59744746e+02  2.03905561e+02 -3.70014856e+02  3.96636984e+02
#   7.51099870e+02  3.54049734e+02  4.11729389e+02  4.15372298e+02
#  -5.60388496e+02 -1.05808576e+02 -3.45042299e+02 -2.63690120e+02
#  -4.59590101e+02 -3.24454726e+02 -5.82625610e+02  1.42990868e+03
#   4.72339875e+02  2.49796589e+02 -1.64881770e+02 -1.61884088e+02
#  -2.00583819e+02 -2.20773790e+02 -1.85921208e+02 -3.62274456e+02
#  -2.25654865e+02  1.43279887e+01 -1.58203251e+02 -3.32209069e+02
#  -7.04767638e+02 -3.24871195e+02 -1.26811817e+02 -2.41563439e+02
#  -4.84092388e+02 -5.54539306e+02 -3.29645451e+02 -9.06221590e+02
#  -8.63737694e+01]
# (18059,)
# (18059,)
